# %%
import posix_ipc
import time
import os

class IPCLock:
    def __init__(self, name):
        self.sem = posix_ipc.Semaphore(
            name,
            flags=posix_ipc.O_CREAT,  # 不存在则创建
            # | posix_ipc.SEM_UNDO,
            # mode=0o600,  # 权限：用户读写
            mode=384,
            initial_value=1,  # 初始为可用状态
        )
        self.owner_pid = None  # 记录持有者进程ID

    def acquire(self, blocking=True, timeout=None):
        """获取锁核心逻辑"""
        if blocking and timeout is not None:
            return self._acquire_with_timeout(timeout)

        acquired = self.sem.acquire(blocking)
        if acquired:
            self.owner_pid = os.getpid()
        return acquired

    def release(self):
        """释放锁并校验持有者"""
        if self.owner_pid != os.getpid():
            raise PermissionError("非持有进程禁止释放锁")
        self.sem.release()
        self.owner_pid = None

    def _acquire_with_timeout(self, timeout):
        """带超时的获取锁实现"""
        end_time = time.time() + timeout
        while time.time() < end_time:
            if self.sem.acquire(blocking=False):
                self.owner_pid = os.getpid()
                return True
            time.sleep(0.05)  # 避免CPU空转
        return False

    def __enter__(self):
        self.acquire()
        return self

    def __exit__(self, *args):
        self.release()

# %%
import os

os.environ["PYTHONUNBUFFERED"] = "1"

import time
import random
from datetime import datetime

from dask.distributed import (
    Client,
    LocalCluster,
    get_worker,
    wait,
    Lock,
)

# NOTE: adjust the number of workers as needed. The more the sooner of crash.
n_workers = 6


def dummy_task(i):
    lock = IPCLock("/my_lock")
    if lock.acquire(blocking=False, timeout=2):
        try:
            print(
                f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")} worker#{get_worker().name} acquired lock and completed task #{i}'
            )
        finally:
            lock.release()
    else:
        print(
            f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")} worker#{get_worker().name} lock not acquired due to timeout. task #{i}'
        )

    return None


def main():
    cluster = LocalCluster(
        n_workers=n_workers,
        threads_per_worker=1,
        processes=True,
    )
    client = Client(cluster)

    futures = []
    i = 0
    while True:
        futures.append(
            client.submit(
                dummy_task,
                i,
            )
        )
        if len(futures) > n_workers * 2:
            _, undone = wait(futures, return_when="FIRST_COMPLETED")
            futures = list(undone)
        i += 1


if __name__ == "__main__":
    main()
# Out:
# 2025-03-01 17:57:36 worker#1 lock not acquired due to timeout. task #0
# 2025-03-01 17:57:36,800 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-b54ba9f7e0d5de2698b731fd89d57c25
# State:     executing
# Task:  <Task 'dummy_task-b54ba9f7e0d5de2698b731fd89d57c25' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,801 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-a950c5810101d037ec29bc5edaf36680
# State:     executing
# Task:  <Task 'dummy_task-a950c5810101d037ec29bc5edaf36680' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,802 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-da0cf8db2dda1e939b461d3411521c02
# State:     executing
# Task:  <Task 'dummy_task-da0cf8db2dda1e939b461d3411521c02' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,802 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-adcb15ed5b95ffb54ffccf6aabc4153b
# State:     executing
# Task:  <Task 'dummy_task-adcb15ed5b95ffb54ffccf6aabc4153b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,803 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-0478c01df715533c2b4d95ff46043797
# State:     executing
# Task:  <Task 'dummy_task-0478c01df715533c2b4d95ff46043797' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,804 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-30888ed484906fd6e97b8a2b58851d96
# State:     executing
# Task:  <Task 'dummy_task-30888ed484906fd6e97b8a2b58851d96' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,806 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-8c9779898fae8e2946f8c782632febc1
# State:     executing
# Task:  <Task 'dummy_task-8c9779898fae8e2946f8c782632febc1' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,807 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-bbd9a283116ee0836d991ec5f46c52c8
# State:     executing
# Task:  <Task 'dummy_task-bbd9a283116ee0836d991ec5f46c52c8' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,807 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-51a91dbb805296250e91b944d86ebe6c
# State:     executing
# Task:  <Task 'dummy_task-51a91dbb805296250e91b944d86ebe6c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,808 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-8fd3b28205108382373b627e530ae0c8
# State:     executing
# Task:  <Task 'dummy_task-8fd3b28205108382373b627e530ae0c8' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,809 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-a9b463d6d96849eb0fc3ae29d122eebe
# State:     executing
# Task:  <Task 'dummy_task-a9b463d6d96849eb0fc3ae29d122eebe' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,810 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-478cff6dd33fcd9c0ad3fb8246df8bf7
# State:     executing
# Task:  <Task 'dummy_task-478cff6dd33fcd9c0ad3fb8246df8bf7' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,816 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-46f35761813c34eb545344dc05b51ee8
# State:     executing
# Task:  <Task 'dummy_task-46f35761813c34eb545344dc05b51ee8' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,825 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-6f5a5a105b383d58e6776caef9da70f0
# State:     executing
# Task:  <Task 'dummy_task-6f5a5a105b383d58e6776caef9da70f0' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,825 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-d059dc7cbdad065f82aa71444bd33979
# State:     executing
# Task:  <Task 'dummy_task-d059dc7cbdad065f82aa71444bd33979' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,826 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-4cef25384cb6a9647cb97c074927c243
# State:     executing
# Task:  <Task 'dummy_task-4cef25384cb6a9647cb97c074927c243' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,828 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-f24d8653c2458272b620148494d7c1ee
# State:     executing
# Task:  <Task 'dummy_task-f24d8653c2458272b620148494d7c1ee' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,831 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-7b1dd4e3f64ed30ce33757e6dc2cc90d
# State:     executing
# Task:  <Task 'dummy_task-7b1dd4e3f64ed30ce33757e6dc2cc90d' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,831 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-4f7ba0881a7a12739e0dd00c32831e20
# State:     executing
# Task:  <Task 'dummy_task-4f7ba0881a7a12739e0dd00c32831e20' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,831 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-5ab79a61d36ff9200b1234f1882d422a
# State:     executing
# Task:  <Task 'dummy_task-5ab79a61d36ff9200b1234f1882d422a' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,832 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-f650e9e7b22c2a89ad8faeec41df45b5
# State:     executing
# Task:  <Task 'dummy_task-f650e9e7b22c2a89ad8faeec41df45b5' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,833 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ef5cd14166b6794104beddb445b05ddf
# State:     executing
# Task:  <Task 'dummy_task-ef5cd14166b6794104beddb445b05ddf' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,834 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-02d3cac319308f1c5b77cd294cc28397
# State:     executing
# Task:  <Task 'dummy_task-02d3cac319308f1c5b77cd294cc28397' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,839 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c6ab3561f0ee4d3ce685a0de3ca9f968
# State:     executing
# Task:  <Task 'dummy_task-c6ab3561f0ee4d3ce685a0de3ca9f968' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,839 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-62660eedeb4861aae43fb16615755ed4
# State:     executing
# Task:  <Task 'dummy_task-62660eedeb4861aae43fb16615755ed4' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,846 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-56a81f5aff904510b162019615ec7544
# State:     executing
# Task:  <Task 'dummy_task-56a81f5aff904510b162019615ec7544' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,846 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-814fa7ac2f20cdab0c8a0d906aad131a
# State:     executing
# Task:  <Task 'dummy_task-814fa7ac2f20cdab0c8a0d906aad131a' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,850 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c358448999f0d1ba84823a640b2a5c73
# State:     executing
# Task:  <Task 'dummy_task-c358448999f0d1ba84823a640b2a5c73' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,853 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-094711c70ae98f31a2c3b6cc78c790c3
# State:     executing
# Task:  <Task 'dummy_task-094711c70ae98f31a2c3b6cc78c790c3' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,853 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-96bc1edfe2ebb715b5008f9953d97546
# State:     executing
# Task:  <Task 'dummy_task-96bc1edfe2ebb715b5008f9953d97546' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,854 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-54a56b81fa5653b985cf9b00ddf87487
# State:     executing
# Task:  <Task 'dummy_task-54a56b81fa5653b985cf9b00ddf87487' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,856 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-00b4ec120150c4d3b81b3d0773960960
# State:     executing
# Task:  <Task 'dummy_task-00b4ec120150c4d3b81b3d0773960960' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,857 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-f851f30c53cbe4c96595f98cbb8f55bb
# State:     executing
# Task:  <Task 'dummy_task-f851f30c53cbe4c96595f98cbb8f55bb' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,860 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-94ecc79bac8c0298166102c53c4a749c
# State:     executing
# Task:  <Task 'dummy_task-94ecc79bac8c0298166102c53c4a749c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,861 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c7048b1f01f64a5ab47b65f0e6f48a25
# State:     executing
# Task:  <Task 'dummy_task-c7048b1f01f64a5ab47b65f0e6f48a25' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,861 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-1faa5af35e25090c3442358eb67f5737
# State:     executing
# Task:  <Task 'dummy_task-1faa5af35e25090c3442358eb67f5737' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,861 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-a134f83ee4e0cd454e3c8ea831bd8109
# State:     executing
# Task:  <Task 'dummy_task-a134f83ee4e0cd454e3c8ea831bd8109' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,861 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c72f794f3bbe7d58e0419d6b5bf67b7f
# State:     executing
# Task:  <Task 'dummy_task-c72f794f3bbe7d58e0419d6b5bf67b7f' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,864 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-e0a890d297c2ad5bc647a765ae420ff8
# State:     executing
# Task:  <Task 'dummy_task-e0a890d297c2ad5bc647a765ae420ff8' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,866 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-b9ff34967f504370a4342c7ccfacf432
# State:     executing
# Task:  <Task 'dummy_task-b9ff34967f504370a4342c7ccfacf432' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,867 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-195b23f5d04c23ee304d2ca2bf95cdd3
# State:     executing
# Task:  <Task 'dummy_task-195b23f5d04c23ee304d2ca2bf95cdd3' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,873 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-e0e320b7e9b4871bce8c267c354951c4
# State:     executing
# Task:  <Task 'dummy_task-e0e320b7e9b4871bce8c267c354951c4' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,873 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-fa894b106e5245c5f5c28d0e61f1642d
# State:     executing
# Task:  <Task 'dummy_task-fa894b106e5245c5f5c28d0e61f1642d' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,878 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-de7b5033fb57ed426351ba96b59c9db7
# State:     executing
# Task:  <Task 'dummy_task-de7b5033fb57ed426351ba96b59c9db7' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,879 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-182fa58b628b14180f17f35a3ef88c75
# State:     executing
# Task:  <Task 'dummy_task-182fa58b628b14180f17f35a3ef88c75' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,880 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-2dd067f3cbbf85acdacb97daf687321b
# State:     executing
# Task:  <Task 'dummy_task-2dd067f3cbbf85acdacb97daf687321b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,881 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-0bba37cec1b531b7b7610e1a0592cee7
# State:     executing
# Task:  <Task 'dummy_task-0bba37cec1b531b7b7610e1a0592cee7' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,884 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-d38ea610ad3bd46161c5c4bd5a16bd2c
# State:     executing
# Task:  <Task 'dummy_task-d38ea610ad3bd46161c5c4bd5a16bd2c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,884 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-612092279859086f74e09c1de78e33dc
# State:     executing
# Task:  <Task 'dummy_task-612092279859086f74e09c1de78e33dc' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,885 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-123319777d7d0e46fbd9473550e9d47d
# State:     executing
# Task:  <Task 'dummy_task-123319777d7d0e46fbd9473550e9d47d' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,889 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-6da0a889210d46927fef90eefd6a670e
# State:     executing
# Task:  <Task 'dummy_task-6da0a889210d46927fef90eefd6a670e' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,889 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-0775fdd404349e285581cb9bd393bb1e
# State:     executing
# Task:  <Task 'dummy_task-0775fdd404349e285581cb9bd393bb1e' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,890 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c6c56c701f2f0d53f5d280e3ed5a000e
# State:     executing
# Task:  <Task 'dummy_task-c6c56c701f2f0d53f5d280e3ed5a000e' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,895 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ce29e75f9fa948a11711cad7bac155b5
# State:     executing
# Task:  <Task 'dummy_task-ce29e75f9fa948a11711cad7bac155b5' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,896 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ed8b5747420597ced4cae1a4b4363782
# State:     executing
# Task:  <Task 'dummy_task-ed8b5747420597ced4cae1a4b4363782' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,901 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-159440cb54bec46d31b15a3413387dde
# State:     executing
# Task:  <Task 'dummy_task-159440cb54bec46d31b15a3413387dde' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,904 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-1bb1a8a781a33aa9cb1b0db39f6c53c1
# State:     executing
# Task:  <Task 'dummy_task-1bb1a8a781a33aa9cb1b0db39f6c53c1' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,904 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-34925195a93f7b4e8ef3e91515491e6b
# State:     executing
# Task:  <Task 'dummy_task-34925195a93f7b4e8ef3e91515491e6b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,904 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-74097664b1d170a61ed4643e0117b2c9
# State:     executing
# Task:  <Task 'dummy_task-74097664b1d170a61ed4643e0117b2c9' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,905 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ac3be7379be57fb33d93e2efc598d714
# State:     executing
# Task:  <Task 'dummy_task-ac3be7379be57fb33d93e2efc598d714' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,906 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-0cae1eb71106d9689b284be89951ca83
# State:     executing
# Task:  <Task 'dummy_task-0cae1eb71106d9689b284be89951ca83' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,907 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-23c7d0d20201bfa58edebf6a68b61174
# State:     executing
# Task:  <Task 'dummy_task-23c7d0d20201bfa58edebf6a68b61174' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,907 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-26631f5a5ef7b95afab7751c1d3a5bd1
# State:     executing
# Task:  <Task 'dummy_task-26631f5a5ef7b95afab7751c1d3a5bd1' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,911 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-848effd3c86f12afa45354706a012e6b
# State:     executing
# Task:  <Task 'dummy_task-848effd3c86f12afa45354706a012e6b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,918 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-df31af449270ace83a73cedbf706c2fe
# State:     executing
# Task:  <Task 'dummy_task-df31af449270ace83a73cedbf706c2fe' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,919 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-d0948e65bb65dd00825c625d38f9b55d
# State:     executing
# Task:  <Task 'dummy_task-d0948e65bb65dd00825c625d38f9b55d' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,919 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-358c91f808d3951fbec93349b82e072c
# State:     executing
# Task:  <Task 'dummy_task-358c91f808d3951fbec93349b82e072c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,919 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-331281783ecdf08b1fe469b1f45fa8a0
# State:     executing
# Task:  <Task 'dummy_task-331281783ecdf08b1fe469b1f45fa8a0' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,924 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-8636bb73e4ce624fd531730d6fcddcf4
# State:     executing
# Task:  <Task 'dummy_task-8636bb73e4ce624fd531730d6fcddcf4' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,925 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-4476205eedf72da9ddfe63b0b136bb62
# State:     executing
# Task:  <Task 'dummy_task-4476205eedf72da9ddfe63b0b136bb62' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,925 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-460bcf61e76768f52d3c51cdb9e31a9b
# State:     executing
# Task:  <Task 'dummy_task-460bcf61e76768f52d3c51cdb9e31a9b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,925 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-00e04b873f6daf0b220e5728e04cdc12
# State:     executing
# Task:  <Task 'dummy_task-00e04b873f6daf0b220e5728e04cdc12' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,925 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-af41cd989de545b19c8d1a3a3efde86c
# State:     executing
# Task:  <Task 'dummy_task-af41cd989de545b19c8d1a3a3efde86c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,926 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-96c80c521f142ac109a7d64e38244227
# State:     executing
# Task:  <Task 'dummy_task-96c80c521f142ac109a7d64e38244227' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,930 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-16d2ce642293948fe6ad714485cfb232
# State:     executing
# Task:  <Task 'dummy_task-16d2ce642293948fe6ad714485cfb232' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,930 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-a6aae7d6721ee704b7f37db48be6f39e
# State:     executing
# Task:  <Task 'dummy_task-a6aae7d6721ee704b7f37db48be6f39e' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,966 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-0d00a3b00f6bfd9800ab0900dea8619b
# State:     executing
# Task:  <Task 'dummy_task-0d00a3b00f6bfd9800ab0900dea8619b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,973 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-58aa7490e727267f927f973b2055452b
# State:     executing
# Task:  <Task 'dummy_task-58aa7490e727267f927f973b2055452b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,973 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c0f1cc497fc19fa8e8517ddf5c858a8e
# State:     executing
# Task:  <Task 'dummy_task-c0f1cc497fc19fa8e8517ddf5c858a8e' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,973 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ddaf4a0985300b93794dc0ba9371478e
# State:     executing
# Task:  <Task 'dummy_task-ddaf4a0985300b93794dc0ba9371478e' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,973 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-70203c5280eecf22fde76a512c401a7a
# State:     executing
# Task:  <Task 'dummy_task-70203c5280eecf22fde76a512c401a7a' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,975 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-8c8e3eb00b15fb7d4e4379293b8a2748
# State:     executing
# Task:  <Task 'dummy_task-8c8e3eb00b15fb7d4e4379293b8a2748' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,979 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-cd82763bc15143533319f08547b47af1
# State:     executing
# Task:  <Task 'dummy_task-cd82763bc15143533319f08547b47af1' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,980 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-88951d4a02f5cb4769735f7ae7e4624b
# State:     executing
# Task:  <Task 'dummy_task-88951d4a02f5cb4769735f7ae7e4624b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,985 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-d1ff2ce34fca272fab14fc91b6a2f871
# State:     executing
# Task:  <Task 'dummy_task-d1ff2ce34fca272fab14fc91b6a2f871' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,985 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-10025558719ee7f0204c09ca24956e9c
# State:     executing
# Task:  <Task 'dummy_task-10025558719ee7f0204c09ca24956e9c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,986 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-a4514f608af7ca311e131919534832e2
# State:     executing
# Task:  <Task 'dummy_task-a4514f608af7ca311e131919534832e2' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,987 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-2e6bc4b5428138a2bea93791191170b2
# State:     executing
# Task:  <Task 'dummy_task-2e6bc4b5428138a2bea93791191170b2' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,988 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-25f6c9e689de83689ef37253afe58a43
# State:     executing
# Task:  <Task 'dummy_task-25f6c9e689de83689ef37253afe58a43' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,992 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-999de2fe5bfadd54f259d523a34b0aa5
# State:     executing
# Task:  <Task 'dummy_task-999de2fe5bfadd54f259d523a34b0aa5' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,992 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-6f5d6b6082e59267c7f2f50e7cb4c71a
# State:     executing
# Task:  <Task 'dummy_task-6f5d6b6082e59267c7f2f50e7cb4c71a' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,999 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-d5897c542bdcc474090f91c63b570b89
# State:     executing
# Task:  <Task 'dummy_task-d5897c542bdcc474090f91c63b570b89' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,999 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-136645a3a3063d70e7a25241e671e5ca
# State:     executing
# Task:  <Task 'dummy_task-136645a3a3063d70e7a25241e671e5ca' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:36,999 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-608ed2ae1bf3f15fd2b537b7c0592b04
# State:     executing
# Task:  <Task 'dummy_task-608ed2ae1bf3f15fd2b537b7c0592b04' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:37,001 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-fe0df7e6ddb19d1dda832561c243fc93
# State:     executing
# Task:  <Task 'dummy_task-fe0df7e6ddb19d1dda832561c243fc93' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:37,005 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-a8aa3a82921e98b104f79c8b465b2901
# State:     executing
# Task:  <Task 'dummy_task-a8aa3a82921e98b104f79c8b465b2901' dummy_task(...)>
# ...
# Key:       dummy_task-bc8f868f5202b41bb1da91a455f32559
# State:     executing
# Task:  <Task 'dummy_task-bc8f868f5202b41bb1da91a455f32559' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,101 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-2443a198223d263841ca6deb478e2fe1
# State:     executing
# Task:  <Task 'dummy_task-2443a198223d263841ca6deb478e2fe1' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,101 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-3592e357e98180fccf52b3319e19421a
# State:     executing
# Task:  <Task 'dummy_task-3592e357e98180fccf52b3319e19421a' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,102 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-55f56698c25dd93ba108884d4c2f1246
# State:     executing
# Task:  <Task 'dummy_task-55f56698c25dd93ba108884d4c2f1246' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,106 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c5ecaa45c6e153ab61bbfe8891ecd7c1
# State:     executing
# Task:  <Task 'dummy_task-c5ecaa45c6e153ab61bbfe8891ecd7c1' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,106 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-490bb7f1b435ea475977b8d10bf0af4b
# State:     executing
# Task:  <Task 'dummy_task-490bb7f1b435ea475977b8d10bf0af4b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,107 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-e769ff88d2b29407e1b4a402f9bba012
# State:     executing
# Task:  <Task 'dummy_task-e769ff88d2b29407e1b4a402f9bba012' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,112 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-0c575f6e00cc6271708d5446a5c01e4d
# State:     executing
# Task:  <Task 'dummy_task-0c575f6e00cc6271708d5446a5c01e4d' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,113 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-758d6c508e1e886c731eb119b3798ad5
# State:     executing
# Task:  <Task 'dummy_task-758d6c508e1e886c731eb119b3798ad5' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,114 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-65ebbee018544fe8cf807ebda8678c9d
# State:     executing
# Task:  <Task 'dummy_task-65ebbee018544fe8cf807ebda8678c9d' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,127 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-bd1d088bceb51cceeab5923f21e0bace
# State:     executing
# Task:  <Task 'dummy_task-bd1d088bceb51cceeab5923f21e0bace' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,129 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-fbaed368c687d912cb7d9e0cf3b71589
# State:     executing
# Task:  <Task 'dummy_task-fbaed368c687d912cb7d9e0cf3b71589' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,130 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-3aaa116dcdad4350e7da747d52615c75
# State:     executing
# Task:  <Task 'dummy_task-3aaa116dcdad4350e7da747d52615c75' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,131 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-1966c8b7be646f5c7378f4ade64c1513
# State:     executing
# Task:  <Task 'dummy_task-1966c8b7be646f5c7378f4ade64c1513' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,131 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-23195e349af804a92883ad47ad50cc10
# State:     executing
# Task:  <Task 'dummy_task-23195e349af804a92883ad47ad50cc10' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,137 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-77f1666f3539690840cc54de31c82d2a
# State:     executing
# Task:  <Task 'dummy_task-77f1666f3539690840cc54de31c82d2a' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,139 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-579b7620b0b6a09d9b493f513e817e4f
# State:     executing
# Task:  <Task 'dummy_task-579b7620b0b6a09d9b493f513e817e4f' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,139 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-6f84f81a38efb28204955799277ceacd
# State:     executing
# Task:  <Task 'dummy_task-6f84f81a38efb28204955799277ceacd' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,142 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c4ab0c4120d5f4e3aee34046e5745369
# State:     executing
# Task:  <Task 'dummy_task-c4ab0c4120d5f4e3aee34046e5745369' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,145 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-144ad701aa53af5c20433118c6f5544a
# State:     executing
# Task:  <Task 'dummy_task-144ad701aa53af5c20433118c6f5544a' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,147 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-285bcdbacd33eebbe3b967e51ec08f79
# State:     executing
# Task:  <Task 'dummy_task-285bcdbacd33eebbe3b967e51ec08f79' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,148 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-02ea84d856df7471e07432bd758b774b
# State:     executing
# Task:  <Task 'dummy_task-02ea84d856df7471e07432bd758b774b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,148 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-e975a17ddbead7c7727b02b1867a23f4
# State:     executing
# Task:  <Task 'dummy_task-e975a17ddbead7c7727b02b1867a23f4' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
#
# 2025-03-01 17:57:41,150 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-8c325f9ce13b9d750f8b3bb6ca578d62
# State:     executing
# Task:  <Task 'dummy_task-8c325f9ce13b9d750f8b3bb6ca578d62' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/990653539.py", line 23, in dummy_task\n  File "/var/folders/cy/bhfxm8116cq_nrfpdywmf9w00000gn/T/ipykernel_83820/398838656.py", line 22, in acquire\n'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 62
#      58         i += 1
#      61 if __name__ == "__main__":
# ---> 62     main()
#
# Cell In[3], line 56, in main()
#      49 futures.append(
#      50     client.submit(
#      51         dummy_task,
#      52         i,
#      53     )
#      54 )
#      55 if len(futures) > n_workers * 2:
# ---> 56     _, undone = wait(futures, return_when="FIRST_COMPLETED")
#      57     futures = list(undone)
#      58 i += 1
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/distributed/client.py:5715, in wait(fs, timeout, return_when)
#    5713     timeout = parse_timedelta(timeout, default="s")
#    5714 client = default_client()
# -> 5715 result = client.sync(_wait, fs, timeout=timeout, return_when=return_when)
#    5716 return result
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/distributed/utils.py:363, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     361     return future
#     362 else:
# --> 363     return sync(
#     364         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     365     )
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/distributed/utils.py:436, in sync(loop, func, callback_timeout, *args, **kwargs)
#     434 else:
#     435     while not e.is_set():
# --> 436         wait(10)
#     438 if error is not None:
#     439     raise error
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/distributed/utils.py:425, in sync.<locals>.wait(timeout)
#     423 def wait(timeout: float | None) -> bool:
#     424     try:
# --> 425         return e.wait(timeout)
#     426     except KeyboardInterrupt:
#     427         loop.add_callback(cancel)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# 2025-03-03 02:36:39,289 - distributed.scheduler - WARNING - Worker failed to heartbeat for 659s; attempting restart: <WorkerState 'tcp://127.0.0.1:62400', name: 1, status: running, memory: 0, processing: 0>
# 2025-03-03 02:36:39,289 - distributed.scheduler - WARNING - Worker failed to heartbeat for 659s; attempting restart: <WorkerState 'tcp://127.0.0.1:62401', name: 0, status: running, memory: 0, processing: 0>
# 2025-03-03 02:36:39,290 - distributed.scheduler - WARNING - Worker failed to heartbeat for 659s; attempting restart: <WorkerState 'tcp://127.0.0.1:62402', name: 2, status: running, memory: 0, processing: 0>
# 2025-03-03 02:36:39,290 - distributed.scheduler - WARNING - Worker failed to heartbeat for 659s; attempting restart: <WorkerState 'tcp://127.0.0.1:62409', name: 3, status: running, memory: 0, processing: 0>
# 2025-03-03 02:36:39,290 - distributed.scheduler - WARNING - Worker failed to heartbeat for 659s; attempting restart: <WorkerState 'tcp://127.0.0.1:62410', name: 5, status: running, memory: 0, processing: 0>
# 2025-03-03 02:36:39,290 - distributed.scheduler - WARNING - Worker failed to heartbeat for 659s; attempting restart: <WorkerState 'tcp://127.0.0.1:62411', name: 4, status: running, memory: 0, processing: 0>
# 2025-03-03 02:36:39,392 - distributed.nanny - WARNING - Restarting worker
# 2025-03-03 02:36:39,403 - distributed.nanny - WARNING - Restarting worker
# 2025-03-03 02:36:39,405 - distributed.nanny - WARNING - Restarting worker
# 2025-03-03 02:36:39,410 - distributed.nanny - WARNING - Restarting worker
# 2025-03-03 02:36:39,415 - distributed.nanny - WARNING - Restarting worker
# 2025-03-03 02:36:39,424 - distributed.nanny - WARNING - Restarting worker
