# %%
import posix_ipc
import time
import os

class IPCLock:
    def __init__(self, name):
        self.sem = posix_ipc.Semaphore(
            name,
            flags=posix_ipc.O_CREAT,  # 不存在则创建
            # | posix_ipc.SEM_UNDO,
            # mode=0o600,  # 权限：用户读写
            mode=384,
            initial_value=1,  # 初始为可用状态
        )
        self.owner_pid = None  # 记录持有者进程ID

    def acquire(self, blocking=True, timeout=None):
        """获取锁核心逻辑"""
        if blocking and timeout is not None:
            return self._acquire_with_timeout(timeout)

        acquired = self.sem.acquire(blocking)
        if acquired:
            self.owner_pid = os.getpid()
        return acquired

    def release(self):
        """释放锁并校验持有者"""
        if self.owner_pid != os.getpid():
            raise PermissionError("非持有进程禁止释放锁")
        self.sem.release()
        self.owner_pid = None

    def _acquire_with_timeout(self, timeout):
        """带超时的获取锁实现"""
        end_time = time.time() + timeout
        while time.time() < end_time:
            if self.sem.acquire(blocking=False):
                self.owner_pid = os.getpid()
                return True
            time.sleep(0.05)  # 避免CPU空转
        return False

    def __enter__(self):
        self.acquire()
        return self

    def __exit__(self, *args):
        self.release()

# %%
import os

os.environ["PYTHONUNBUFFERED"] = "1"

import time
import random
from datetime import datetime

from dask.distributed import (
    Client,
    LocalCluster,
    get_worker,
    wait,
    Lock,
)

# NOTE: adjust the number of workers as needed. The more the sooner of crash.
n_workers = 6


def dummy_task(i):
    lock = IPCLock("/my_lock")
    if lock.acquire(blocking=False, timeout=2):
        try:
            print(
                f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")} worker#{get_worker().name} acquired lock and completed task #{i}'
            )
        finally:
            lock.release()
    else:
        print(
            f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")} worker#{get_worker().name} lock not acquired due to timeout. task #{i}'
        )

    return None


def main():
    cluster = LocalCluster(
        n_workers=n_workers,
        threads_per_worker=1,
        processes=True,
    )
    client = Client(cluster)

    futures = []
    i = 0
    while True:
        futures.append(
            client.submit(
                dummy_task,
                i,
            )
        )
        if len(futures) > n_workers * 2:
            _, undone = wait(futures, return_when="FIRST_COMPLETED")
            futures = list(undone)
        i += 1


if __name__ == "__main__":
    main()
# Out:
# /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 52260 instead
#   warnings.warn(
# 2025-02-28 15:36:28,051 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-06a9e2238d174d970b600cbec89d76b3
# State:     executing
# Task:  <Task 'dummy_task-06a9e2238d174d970b600cbec89d76b3' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,055 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-2a84c79009774a877af12d7031d6bfdd
# State:     executing
# Task:  <Task 'dummy_task-2a84c79009774a877af12d7031d6bfdd' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,061 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-a397e4fcfeebf8f0212216a833775836
# State:     executing
# Task:  <Task 'dummy_task-a397e4fcfeebf8f0212216a833775836' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,065 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ae800c116732800c682efc433460a8a4
# State:     executing
# Task:  <Task 'dummy_task-ae800c116732800c682efc433460a8a4' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,068 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-67ac790eeacdba6eea832b5836a98cc6
# State:     executing
# Task:  <Task 'dummy_task-67ac790eeacdba6eea832b5836a98cc6' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,078 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c0d809badbdfb2b53b7e4743e18714ac
# State:     executing
# Task:  <Task 'dummy_task-c0d809badbdfb2b53b7e4743e18714ac' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,084 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-d59249f271a742c84b4f4c4a554effb0
# State:     executing
# Task:  <Task 'dummy_task-d59249f271a742c84b4f4c4a554effb0' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,086 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ccc13a9c020c8f5ab8816e7a9195c41f
# State:     executing
# Task:  <Task 'dummy_task-ccc13a9c020c8f5ab8816e7a9195c41f' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,101 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c52746ec12e5a2e040a2a508511a7fdd
# State:     executing
# Task:  <Task 'dummy_task-c52746ec12e5a2e040a2a508511a7fdd' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,106 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-135b951a5b901738af18efa123b991e5
# State:     executing
# Task:  <Task 'dummy_task-135b951a5b901738af18efa123b991e5' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,112 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ddb6cf6183e16218b142545130babb24
# State:     executing
# Task:  <Task 'dummy_task-ddb6cf6183e16218b142545130babb24' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,121 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-5d6c80a66446aa51bbe128d27fdf7f77
# State:     executing
# Task:  <Task 'dummy_task-5d6c80a66446aa51bbe128d27fdf7f77' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,140 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-cc952f6c49d2c978d3b3639bef786d4d
# State:     executing
# Task:  <Task 'dummy_task-cc952f6c49d2c978d3b3639bef786d4d' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,143 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-b6e447bf2171fbb9f76dc6f836ae44e2
# State:     executing
# Task:  <Task 'dummy_task-b6e447bf2171fbb9f76dc6f836ae44e2' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,146 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-d1f37c4b8b7c06c9b0d9c90a597685a0
# State:     executing
# Task:  <Task 'dummy_task-d1f37c4b8b7c06c9b0d9c90a597685a0' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,155 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-78a7961e35ebad08a9615cceedce6f7b
# State:     executing
# Task:  <Task 'dummy_task-78a7961e35ebad08a9615cceedce6f7b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,179 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-b70bc8608a63133ba7177c0ee409d070
# State:     executing
# Task:  <Task 'dummy_task-b70bc8608a63133ba7177c0ee409d070' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,184 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-1eec8c46ad911fbc81a3d71978bfa992
# State:     executing
# Task:  <Task 'dummy_task-1eec8c46ad911fbc81a3d71978bfa992' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,194 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ffe39566a50b26c887727fdc245fd165
# State:     executing
# Task:  <Task 'dummy_task-ffe39566a50b26c887727fdc245fd165' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,203 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ac8ea6989e4fe68ceec867fa65e1d437
# State:     executing
# Task:  <Task 'dummy_task-ac8ea6989e4fe68ceec867fa65e1d437' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,207 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-8b6a55623bb63ccf14f324f6c2b2950b
# State:     executing
# Task:  <Task 'dummy_task-8b6a55623bb63ccf14f324f6c2b2950b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,213 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-5d4e151a7a149eda543b673a8ccf7a61
# State:     executing
# Task:  <Task 'dummy_task-5d4e151a7a149eda543b673a8ccf7a61' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,241 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-6d78013749e7dde2e85aeb383bed5cf7
# State:     executing
# Task:  <Task 'dummy_task-6d78013749e7dde2e85aeb383bed5cf7' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,244 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-26305b76e435b788bd6b4eb85ebf2d4a
# State:     executing
# Task:  <Task 'dummy_task-26305b76e435b788bd6b4eb85ebf2d4a' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,250 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-501ffc01db77b47f42a73e9819c87f70
# State:     executing
# Task:  <Task 'dummy_task-501ffc01db77b47f42a73e9819c87f70' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,269 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-e23c6cd59f96eba31f0953a290d91299
# State:     executing
# Task:  <Task 'dummy_task-e23c6cd59f96eba31f0953a290d91299' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,276 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-74ce3a670c59f9e7ba04946c7d6e6a8c
# State:     executing
# Task:  <Task 'dummy_task-74ce3a670c59f9e7ba04946c7d6e6a8c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,283 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-521923d7b432efaf38a668d227916bb5
# State:     executing
# Task:  <Task 'dummy_task-521923d7b432efaf38a668d227916bb5' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,292 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-2e73bb8917477cc21048bb361378b5f3
# State:     executing
# Task:  <Task 'dummy_task-2e73bb8917477cc21048bb361378b5f3' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,314 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-9a52cbcc203dab850fb61af34dfdd64b
# State:     executing
# Task:  <Task 'dummy_task-9a52cbcc203dab850fb61af34dfdd64b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,316 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-2b03f33f068f18fefc9ddad45e3b7ed1
# State:     executing
# Task:  <Task 'dummy_task-2b03f33f068f18fefc9ddad45e3b7ed1' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,321 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-0483e2c33cf0f207177fbae8578d7170
# State:     executing
# Task:  <Task 'dummy_task-0483e2c33cf0f207177fbae8578d7170' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,342 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-f5767c96963f662e0cb5e1bdb56137e2
# State:     executing
# Task:  <Task 'dummy_task-f5767c96963f662e0cb5e1bdb56137e2' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,343 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-68fad6fc66966406473804f27275373e
# State:     executing
# Task:  <Task 'dummy_task-68fad6fc66966406473804f27275373e' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,347 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-13f35c5aa0ab1de03cfeae5170be4df1
# State:     executing
# Task:  <Task 'dummy_task-13f35c5aa0ab1de03cfeae5170be4df1' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,356 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-27c92d44783282ca99610446c260e1ab
# State:     executing
# Task:  <Task 'dummy_task-27c92d44783282ca99610446c260e1ab' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,372 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-1ef88e6db991b982e2517183ca378a6d
# State:     executing
# Task:  <Task 'dummy_task-1ef88e6db991b982e2517183ca378a6d' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,379 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-27e4a1d2ccfb91cf3e2bed92af28f83c
# State:     executing
# Task:  <Task 'dummy_task-27e4a1d2ccfb91cf3e2bed92af28f83c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,393 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-1cde2be37f6ffe0ca55399a2e7dc6dd7
# State:     executing
# Task:  <Task 'dummy_task-1cde2be37f6ffe0ca55399a2e7dc6dd7' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,400 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-c8353bad0972416321706bad1548def0
# State:     executing
# Task:  <Task 'dummy_task-c8353bad0972416321706bad1548def0' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,409 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-8f4bebf940376759b55f308fced4c3ed
# State:     executing
# Task:  <Task 'dummy_task-8f4bebf940376759b55f308fced4c3ed' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,416 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-0bd4acbe85f548c201573eed54e18aa6
# State:     executing
# Task:  <Task 'dummy_task-0bd4acbe85f548c201573eed54e18aa6' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,420 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-1201f181d708cd519ad5abf6ab33ccd4
# State:     executing
# Task:  <Task 'dummy_task-1201f181d708cd519ad5abf6ab33ccd4' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,426 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-fbbbe6fb225bfdcb64589e8bb2dcc568
# State:     executing
# Task:  <Task 'dummy_task-fbbbe6fb225bfdcb64589e8bb2dcc568' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,430 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-944303e4d5659da30652823f964a361c
# State:     executing
# Task:  <Task 'dummy_task-944303e4d5659da30652823f964a361c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,452 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-736b6ff0899e47a812836b45cf9e63b6
# State:     executing
# Task:  <Task 'dummy_task-736b6ff0899e47a812836b45cf9e63b6' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,459 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-18848f0937f3532c20063d9d7e74e003
# State:     executing
# Task:  <Task 'dummy_task-18848f0937f3532c20063d9d7e74e003' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,463 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-cbb3287d8d33ff9986c8beead0cc50ab
# State:     executing
# Task:  <Task 'dummy_task-cbb3287d8d33ff9986c8beead0cc50ab' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,489 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-e612e303665782869b84839d76577b39
# State:     executing
# Task:  <Task 'dummy_task-e612e303665782869b84839d76577b39' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,504 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-318a5c2091d33da99e34c47e3d424730
# State:     executing
# Task:  <Task 'dummy_task-318a5c2091d33da99e34c47e3d424730' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,507 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-3a765c5b4553e7d23c46f71b157693bc
# State:     executing
# Task:  <Task 'dummy_task-3a765c5b4553e7d23c46f71b157693bc' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,513 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-e212ab4cf6986137604376aac31986e0
# State:     executing
# Task:  <Task 'dummy_task-e212ab4cf6986137604376aac31986e0' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,524 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-90d12202535019b920d64d50435dc513
# State:     executing
# Task:  <Task 'dummy_task-90d12202535019b920d64d50435dc513' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,532 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-a1ad7078196015d321fcedffc0d2fecd
# State:     executing
# Task:  <Task 'dummy_task-a1ad7078196015d321fcedffc0d2fecd' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,538 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ade28ae404971c45d30d9d374b6f441a
# State:     executing
# Task:  <Task 'dummy_task-ade28ae404971c45d30d9d374b6f441a' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,558 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-880b1cf8abdc40dd8bd6c130152729d1
# State:     executing
# Task:  <Task 'dummy_task-880b1cf8abdc40dd8bd6c130152729d1' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,562 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-f75efca8eb977f0db509d1f58c5a23a5
# State:     executing
# Task:  <Task 'dummy_task-f75efca8eb977f0db509d1f58c5a23a5' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,567 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-7ff1555585bb92871f283d1ff6ca4bbd
# State:     executing
# Task:  <Task 'dummy_task-7ff1555585bb92871f283d1ff6ca4bbd' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,590 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-06dcd71dbc56f166c7916cd2e9130f8b
# State:     executing
# Task:  <Task 'dummy_task-06dcd71dbc56f166c7916cd2e9130f8b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,592 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-32ab0e16f426ec884b2fda1870526021
# State:     executing
# Task:  <Task 'dummy_task-32ab0e16f426ec884b2fda1870526021' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,598 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-cb57f792c21baff009a05558ae0a2e84
# State:     executing
# Task:  <Task 'dummy_task-cb57f792c21baff009a05558ae0a2e84' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,602 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-9f8afcf0d2cac3dc9271bffff7fc7331
# State:     executing
# Task:  <Task 'dummy_task-9f8afcf0d2cac3dc9271bffff7fc7331' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,613 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-f1163cd1d0b55aeddd27b2ce50d25d23
# State:     executing
# Task:  <Task 'dummy_task-f1163cd1d0b55aeddd27b2ce50d25d23' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,638 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-455525154f6e38673d6c8876f08e4c62
# State:     executing
# Task:  <Task 'dummy_task-455525154f6e38673d6c8876f08e4c62' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,642 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-2801a17ca8da1eb3bc3a51dd7cd3e514
# State:     executing
# Task:  <Task 'dummy_task-2801a17ca8da1eb3bc3a51dd7cd3e514' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,646 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ce29372e6a2fc04a3444c9b54d0f1ad7
# State:     executing
# Task:  <Task 'dummy_task-ce29372e6a2fc04a3444c9b54d0f1ad7' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,651 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-26d9af17b09d32cffb4bcd74079ab318
# State:     executing
# Task:  <Task 'dummy_task-26d9af17b09d32cffb4bcd74079ab318' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,680 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ebbb118cf77f70b79bf40164c859344b
# State:     executing
# Task:  <Task 'dummy_task-ebbb118cf77f70b79bf40164c859344b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,680 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-304ab4b05f990b4fc9ed0b6ada9dea15
# State:     executing
# Task:  <Task 'dummy_task-304ab4b05f990b4fc9ed0b6ada9dea15' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,703 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-3e79bb48df15826c4df6b090a9381300
# State:     executing
# Task:  <Task 'dummy_task-3e79bb48df15826c4df6b090a9381300' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,712 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-b1588dc483350267a67b7bd266c76a08
# State:     executing
# Task:  <Task 'dummy_task-b1588dc483350267a67b7bd266c76a08' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,716 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-3240cb27e48c85432b81a8bcb9490158
# State:     executing
# Task:  <Task 'dummy_task-3240cb27e48c85432b81a8bcb9490158' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,717 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-8a766c638c7af3ceb85bc0245ad10f0f
# State:     executing
# Task:  <Task 'dummy_task-8a766c638c7af3ceb85bc0245ad10f0f' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,728 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-baee69904a92170661bbaf58cd8ce051
# State:     executing
# Task:  <Task 'dummy_task-baee69904a92170661bbaf58cd8ce051' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,734 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-3b90e9da4990a60904cefd9944cf961e
# State:     executing
# Task:  <Task 'dummy_task-3b90e9da4990a60904cefd9944cf961e' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,737 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-48b5b27cb5eeff40a411f0602f242a4c
# State:     executing
# Task:  <Task 'dummy_task-48b5b27cb5eeff40a411f0602f242a4c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,750 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-7050111abf5582fdecd41d4ce86c7475
# State:     executing
# Task:  <Task 'dummy_task-7050111abf5582fdecd41d4ce86c7475' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,767 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-a584cc0237c0bbe34e46b89b1dbabb84
# State:     executing
# Task:  <Task 'dummy_task-a584cc0237c0bbe34e46b89b1dbabb84' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,769 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-78b2cd34df93795f360fa38fae8840fe
# State:     executing
# Task:  <Task 'dummy_task-78b2cd34df93795f360fa38fae8840fe' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,774 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-150db4204845a5693904a245a9fe3dc3
# State:     executing
# Task:  <Task 'dummy_task-150db4204845a5693904a245a9fe3dc3' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,778 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-2d4014d7effb89b6eaf7cae4923a2440
# State:     executing
# Task:  <Task 'dummy_task-2d4014d7effb89b6eaf7cae4923a2440' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,785 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-4a757a1f1a1c0c8766200c4c05cd4e6c
# State:     executing
# Task:  <Task 'dummy_task-4a757a1f1a1c0c8766200c4c05cd4e6c' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,808 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-5590c8d5ea7484ab4198d36d2e5cb258
# State:     executing
# Task:  <Task 'dummy_task-5590c8d5ea7484ab4198d36d2e5cb258' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,811 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-50868c22e9807bff0027f3aaeadbce7b
# State:     executing
# Task:  <Task 'dummy_task-50868c22e9807bff0027f3aaeadbce7b' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,816 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-6fffbd7adc639cf3e1d8c518789d7c3d
# State:     executing
# Task:  <Task 'dummy_task-6fffbd7adc639cf3e1d8c518789d7c3d' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,819 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-0400b87f48d3876dbadba6276f1f4887
# State:     executing
# Task:  <Task 'dummy_task-0400b87f48d3876dbadba6276f1f4887' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,842 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-35b87d54a085d7c1c9d11a95bb25cf10
# State:     executing
# Task:  <Task 'dummy_task-35b87d54a085d7c1c9d11a95bb25cf10' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,848 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-ce77dde1a3a658bf693979627bf97634
# State:     executing
# Task:  <Task 'dummy_task-ce77dde1a3a658bf693979627bf97634' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,849 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-01d4aa043c4fcc4d570b71c380e81802
# State:     executing
# Task:  <Task 'dummy_task-01d4aa043c4fcc4d570b71c380e81802' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,863 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-2e9c831e9f1dcb40777b12c6d9d81395
# State:     executing
# Task:  <Task 'dummy_task-2e9c831e9f1dcb40777b12c6d9d81395' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,869 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-edbb13d89ed6bd78d808a1c162e88615
# State:     executing
# Task:  <Task 'dummy_task-edbb13d89ed6bd78d808a1c162e88615' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,886 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-20480464dcd4bb935a7b5be7a4bf1af5
# State:     executing
# Task:  <Task 'dummy_task-20480464dcd4bb935a7b5be7a4bf1af5' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,892 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-4bec2234ea930e0d0afdc4dcf9a0f88d
# State:     executing
# Task:  <Task 'dummy_task-4bec2234ea930e0d0afdc4dcf9a0f88d' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,894 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-aae21dc3d4f071d6d8a3cd632eb0f537
# State:     executing
# Task:  <Task 'dummy_task-aae21dc3d4f071d6d8a3cd632eb0f537' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# 2025-02-28 15:36:28,914 - distributed.worker - ERROR - Compute Failed
# Key:       dummy_task-4145c09cd6fbdcd3de5f31a01bc2b5a4
# State:     executing
# Task:  <Task 'dummy_task-4145c09cd6fbdcd3de5f31a01bc2b5a4' dummy_task(...)>
# Exception: "BusyError('Semaphore is busy')"
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
#
# ...
# Traceback: '  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/990653539.py", line 23, in dummy_task\n  File "/var/folders/fb/phz99gmn7cld34rh4f6ppmlw0000gn/T/ipykernel_87456/398838656.py", line 22, in acquire\n'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 62
#      58         i += 1
#      61 if __name__ == "__main__":
# ---> 62     main()
#
# Cell In[8], line 50, in main()
#      47 i = 0
#      48 while True:
#      49     futures.append(
# ---> 50         client.submit(
#      51             dummy_task,
#      52             i,
#      53         )
#      54     )
#      55     if len(futures) > n_workers * 2:
#      56         _, undone = wait(futures, return_when="FIRST_COMPLETED")
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/client.py:2153, in Client.submit(self, func, key, workers, resources, retries, priority, fifo_timeout, allow_other_workers, actor, actors, pure, *args, **kwargs)
#    2151 if key is None:
#    2152     if pure:
# -> 2153         key = funcname(func) + "-" + tokenize(func, kwargs, *args)
#    2154     else:
#    2155         key = funcname(func) + "-" + str(uuid.uuid4())
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/dask/tokenize.py:76, in tokenize(ensure_deterministic, *args, **kwargs)
#      74     token = _ENSURE_DETERMINISTIC.set(ensure_deterministic)
#      75 try:
# ---> 76     return _tokenize(*args, **kwargs)
#      77 finally:
#      78     if token:
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/dask/tokenize.py:34, in _tokenize(*args, **kwargs)
#      33 def _tokenize(*args: object, **kwargs: object) -> str:
# ---> 34     token: object = _normalize_seq_func(args)
#      35     if kwargs:
#      36         token = token, _normalize_seq_func(sorted(kwargs.items()))
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/dask/tokenize.py:152, in _normalize_seq_func(seq)
#     150 _SEEN[id(seq)] = len(_SEEN), seq
#     151 try:
# --> 152     return tuple(map(_inner_normalize_token, seq))
#     153 finally:
#     154     del _SEEN[id(seq)]
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/dask/tokenize.py:146, in _normalize_seq_func.<locals>._inner_normalize_token(item)
#     144 if isinstance(item, _IDENTITY_DISPATCH):
#     145     return item
# --> 146 return normalize_token(item)
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/dask/utils.py:772, in Dispatch.__call__(self, arg, *args, **kwargs)
#     768 """
#     769 Call the corresponding method based on type of argument.
#     770 """
#     771 meth = self.dispatch(type(arg))
# --> 772 return meth(arg, *args, **kwargs)
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/dask/tokenize.py:208, in normalize_object(o)
#     205     return _normalize_dataclass(o)
#     207 try:
# --> 208     return _normalize_pickle(o)
#     209 except Exception:
#     210     _maybe_raise_nondeterministic(
#     211         f"Object {o!r} cannot be deterministically hashed. See "
#     212         "https://docs.dask.org/en/latest/custom-collections.html#implementing-deterministic-hashing "
#     213         "for more information."
#     214     )
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/dask/tokenize.py:242, in _normalize_pickle(o)
#     240 try:
#     241     out = mod.dumps(o, protocol=5, buffer_callback=buffers.append)
# --> 242     mod.loads(out, buffers=buffers)
#     243     pik2 = hash_buffer_hex(out)
#     244 except Exception:
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:393, in _builtin_type(name)
#     389     if type(v) is type:
#     390         _BUILTIN_TYPE_NAMES[v] = k
# --> 393 def _builtin_type(name):
#     394     if name == "ClassType":  # pragma: no cover
#     395         # Backward compat to load pickle files generated with cloudpickle
#     396         # < 1.3 even if loading pickle files from older versions is not
#     397         # officially supported.
#     398         return type
#
# KeyboardInterrupt:
# 2025-02-28 15:36:32,735 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-02-28 15:36:32,735 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# 2025-02-28 15:36:32,737 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-02-28 15:36:32,737 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# asyncio.exceptions.CancelledError
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# Traceback (most recent call last):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#
# During handling of the above exception, another exception occurred:
#
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
