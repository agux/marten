# %%
import fcntl
import time

class FileLock:
    def __init__(self, lockfile):
        self.lockfile = lockfile
        self.fd = None

    def acquire(self, timeout=10):
        self.fd = open(self.lockfile, 'w')
        start = time.time()
        while True:
            try:
                fcntl.flock(self.fd, fcntl.LOCK_EX | fcntl.LOCK_NB)
                return True
            except BlockingIOError:
                # self.fd.close()
                if time.time() - start > timeout:
                    return False
                time.sleep(0.1)
            except OSError as e:
                # Handle file system errors
                self.fd.close()
                raise e

    def release(self):
        if self.fd:
            fcntl.flock(self.fd, fcntl.LOCK_UN)
            self.fd.close()
            self.fd = None

# %%
import os

os.environ["PYTHONUNBUFFERED"] = "1"

import time
import random
from datetime import datetime

from dask.distributed import (
    Client,
    LocalCluster,
    get_worker,
    wait,
    Lock,
)

# NOTE: adjust the number of workers as needed. The more the sooner of crash.
n_workers = 6


def dummy_task(i):
    lock = FileLock("marten.lock")
    while not lock.acquire(timeout=2):
        time.sleep(0.5)
    try:
        time.sleep(random.uniform(1.5, 3.0))
        print(
            f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")} worker#{get_worker().name} acquired lock and completed task #{i}'
        )
    finally:
        lock.release()

    return None


def main():
    cluster = LocalCluster(
        n_workers=n_workers,
        threads_per_worker=1,
        processes=True,
    )
    client = Client(cluster)

    futures = []
    i = 0
    while True:
        futures.append(
            client.submit(
                dummy_task,
                i,
            )
        )
        if len(futures) > n_workers * 2:
            _, undone = wait(futures, return_when="FIRST_COMPLETED")
            futures = list(undone)
        i += 1


if __name__ == "__main__":
    main()
# Out:
# /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 61155 instead
#   warnings.warn(
# 2025-03-03 10:05:23 worker#3 acquired lock and completed task #0
# 2025-03-03 10:05:24 worker#3 acquired lock and completed task #6
# 2025-03-03 10:05:26 worker#3 acquired lock and completed task #12
# 2025-03-03 10:05:28 worker#3 acquired lock and completed task #13
# 2025-03-03 10:05:31 worker#3 acquired lock and completed task #14
# 2025-03-03 10:05:33 worker#3 acquired lock and completed task #15
# 2025-03-03 10:05:35 worker#3 acquired lock and completed task #16
# 2025-03-03 10:05:36 worker#3 acquired lock and completed task #17
# 2025-03-03 10:05:39 worker#3 acquired lock and completed task #18
# 2025-03-03 10:05:42 worker#3 acquired lock and completed task #19
# 2025-03-03 10:05:45 worker#3 acquired lock and completed task #20
# 2025-03-03 10:05:47 worker#3 acquired lock and completed task #21
# 2025-03-03 10:05:48 worker#3 acquired lock and completed task #22
# 2025-03-03 10:05:51 worker#3 acquired lock and completed task #23
# 2025-03-03 10:05:53 worker#3 acquired lock and completed task #24
# 2025-03-03 10:05:55 worker#3 acquired lock and completed task #25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 60
#      56         i += 1
#      59 if __name__ == "__main__":
# ---> 60     main()
#
# Cell In[12], line 54, in main()
#      47 futures.append(
#      48     client.submit(
#      49         dummy_task,
#      50         i,
#      51     )
#      52 )
#      53 if len(futures) > n_workers * 2:
# ---> 54     _, undone = wait(futures, return_when="FIRST_COMPLETED")
#      55     futures = list(undone)
#      56 i += 1
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/client.py:5714, in wait(fs, timeout, return_when)
#    5712     timeout = parse_timedelta(timeout, default="s")
#    5713 client = default_client()
# -> 5714 result = client.sync(_wait, fs, timeout=timeout, return_when=return_when)
#    5715 return result
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/utils.py:363, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     361     return future
#     362 else:
# --> 363     return sync(
#     364         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     365     )
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/utils.py:436, in sync(loop, func, callback_timeout, *args, **kwargs)
#     434 else:
#     435     while not e.is_set():
# --> 436         wait(10)
#     438 if error is not None:
#     439     raise error
#
# File ~/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/utils.py:425, in sync.<locals>.wait(timeout)
#     423 def wait(timeout: float | None) -> bool:
#     424     try:
# --> 425         return e.wait(timeout)
#     426     except KeyboardInterrupt:
#     427         loop.add_callback(cancel)
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# 2025-03-03 10:05:57,783 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('dummy_task-3e343fa008ec3c039c50969afe265b08')" coro=<Worker.execute() done, defined at /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-03-03 10:05:57,783 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('dummy_task-355fcc02843991c114d636e5f9dfc22f')" coro=<Worker.execute() done, defined at /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-03-03 10:05:57,784 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('dummy_task-6df2db8c5da0c1475b3168fb236194b1')" coro=<Worker.execute() done, defined at /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-03-03 10:05:57,785 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('dummy_task-ccb5cbe5981e17d9ffb950d15e781274')" coro=<Worker.execute() done, defined at /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-03-03 10:05:57,786 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('dummy_task-0f06981808c46879a7dd8c834b035a25')" coro=<Worker.execute() done, defined at /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-03-03 10:05:57,787 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('dummy_task-753ea944fe119e95326f0a72b26bf33a')" coro=<Worker.execute() done, defined at /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2025-03-03 10:05:57,793 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:61175' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'dummy_task-6336e31e49ad63df9e12719926ebea2f'} (stimulus_id='handle-worker-cleanup-1740967557.793185')
# 2025-03-03 10:05:58 worker#3 acquired lock and completed task #26
# 2025-03-03 10:06:00,041 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
# 2025-03-03 10:06:00 worker#0 acquired lock and completed task #3
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
# 2025-03-03 10:06:02 worker#4 acquired lock and completed task #5
# 2025-03-03 10:06:04,528 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
# 2025-03-03 10:06:04 worker#1 acquired lock and completed task #4
# 2025-03-03 10:06:06,702 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
# 2025-03-03 10:06:07 worker#5 acquired lock and completed task #2
# 2025-03-03 10:06:08 worker#2 acquired lock and completed task #1
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/base_events.py", line 685, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
# 2025-03-06 00:15:49,408 - tornado.application - ERROR - Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 14 memory: 202 MB fds: 158>>
# Traceback (most recent call last):
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/psutil/__init__.py", line 2166, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory
