# %% [markdown]
# # NeuralProphet Experiement on Univariate Prediction

# %% [markdown]
# ## Benchmark
#
# | Setup | MAE_val | RMSE_val | Loss_val | diff_mean | diff_std |
# |-------|---------|----------|----------|-----------|----------|
# |[Default](#default)|0.587373|0.871839|0.028389|0.00361|0.962|
# |[Impute](#imputation)|0.587373|0.871839|0.028389|0.00361|0.962|
# |[CP64](#n_changepoints64)|0.591210|0.875714|0.028505|0.00537|0.9605|
# |[CP128](#n_changepoints128)|0.594332|0.878078|0.028654|-0.00785|0.9597|
# |[Quantile](#quantile)|0.588217|0.870637|0.043360|-0.001769|0.96145|
# |[CFM](#conformal-forecast)|0.732499|1.050563|0.063295|0.00255|0.9617|
# |[SR-0.1](#seasonality_reg01)|0.587368|0.871838|0.028390|0.003596|0.962|
# |[SR-0.2](#seasonality_reg02)|0.587364|0.871838|0.028390|0.00358|0.962|
# |[FT-12](#fourier-terms12)|0.570524|0.875814|0.028623|0.00283|0.949|
# |[FT-15](#fourier-terms15)|0.568455|0.875026|0.028481|-0.00367|0.94678|
# |[FT-20](#fourier-terms20)|0.576567|0.881927|0.029018|0.005877|0.943|
# |[FT-30](#fourier-terms30)|0.590277|0.888660|0.029465|-0.009072|0.9335|
# |[FT-50](#fourier-terms50)|0.654222|0.988752|0.035289|0.0016665|0.9228|
# |[FT-100](#fourier-terms100)|0.737353|1.053262|0.040185|-0.00378|0.87996|
# |[SR01+FT30](#sr01ft30)|0.590267|0.888643|0.029465|-0.00907|0.9335|
# |[SR01+FT100](#sr01ft100)|0.737336|1.053240|0.040184|-0.00378|0.87996|
# |[AR-3](#n_lag3)|0.554568|0.832682|0.025705|0.0062|0.9495|
# |[AR-5](#n_lag5)|0.556723|0.822340|0.0252|0.007|0.9488|
# |[AR-10](#n_lag10)|0.559129|0.839416|0.026068|0.01061|0.9492|
# |[AR-30](#n_lag30)|0.625781|0.949518|0.032530|-0.0367|0.9905|
# |[AR5+REG0001](#ar5reg0001)|0.556722|0.822336|0.025200|0.007|0.9488|
# |[AR5+REG001](#ar5reg001)|0.556710|0.822301|0.025199|0.007|0.9488|
# |[AR5+REG2](#ar5reg2)|0.558877|0.823302|0.025423|0.00676|0.94946|
# |[FT15+AR5](#ft15ar5)|<font color="red">0.524882</font>|0.806963|0.024343|-0.00108|0.93|
# |[FT50+AR5](#ft50ar5)|0.621913|0.880796|0.029079|0.0095|0.9022|
# |[FT50+AR10](#ft50ar10)|0.620491|0.889379|0.029569|0.00088|0.90|
# |[FT50+AR30](#ft50ar30)|0.672139|0.933881|0.032711|<font color="red">0.00027</font>|0.875|
# |[ARnet3x16](#3-x-16)|0.587373|0.871839|0.028389|0.0036|0.962|
# |[ARnet3x32](#3-x-32)|0.587373|0.871839|0.028389|0.0036|0.962|
# |[ARnet8x16](#8-x-16)|0.587373|0.871839|0.028389|0.0036|0.962|
# |[AR5+ARnet3x16](#ar5--arnet3x16)|0.809829|1.108074|0.044319|-0.0188|1.0738|
# |[AR5+ARnet32x16](#ar5--arnet32x16)|5.446910|5.521294|0.687986|-5.46|1.19|
# |[FT5+ARnet3x16](#ft5--arnet3x16)|0.587632|0.871830|0.028455|0.00491|0.9623|
# |[FT12+ARnet3x16](#ft12--arnet3x16)|0.570524|0.875814|0.028623|0.00283|0.949|
# |[FT15+ARnet3x16](#ft15--arnet3x16)|0.568455|0.875026|0.028481|-0.00367|0.9468|
# |[FT15+ARnet32x16](#ft15--arnet32x16)|0.568455|0.875026|0.028481|-0.00367|0.9468|
# |[FT20+ARnet3x16](#ft20--arnet3x16)|0.576567|0.881927|0.029018|0.00588|0.943|
# |[FT30+ARnet3x16](#ft30--arnet3x16)|0.590277|0.888660|0.029465|-0.009|0.9335|
# |[FT15,AR5,ARnet2x4](#ft15ar5arnet2x4)|0.537266|0.812472|0.024758|-0.00254|0.929|
# |[FT15,AR5,ARnet2x8](#ft15ar5arnet2x8)|0.825129|1.102384|0.043130|-0.025|1.01|
# |[FT15,AR5,ARnet2x16](#ft15ar5arnet2x16)|0.695665|1.009736|0.036006|-0.0092|1.0385|
# |[FT15,AR5,ARnet3x4](#ft15ar5arnet3x4)|0.732374|1.169223|0.043824|-0.0258|1.055|
# |[FT15,AR5,ARnet3x8](#ft15ar5arnet3x8)|0.562147|0.817704|0.025102|0.0021|0.893|
# |[FT15,AR5,ARnet3x16](#ft15ar5arnet3x16)|0.577676|0.910788|0.029431|-0.0135|0.906|
# |[FT15,AR5,ARnet3x32](#ft15ar5arnet3x32)|0.765017|1.079210|0.040810|-0.0199|0.9884|
# |[FT15,AR5,ARnet4x2](#ft15ar5arnet4x2)|0.540506|0.834793|0.025973|-0.0126|0.935|
# |[FT15,AR5,ARnet4x4](#ft15ar5arnet4x4)|0.531110|<font color="red">0.795895</font>|<font color="red">0.023643</font>|-0.0027|0.911|
# |[FT15,AR5,ARnet4x8](#ft15ar5arnet4x8)|0.539853|0.810724|0.024459|0.01069|0.922|
# |[FT15,AR5,ARnet4x16](#ft15ar5arnet4x16)|0.846374|1.153391|0.045361|-0.03751|1.157|
# |[FT15,AR5,ARnet5x2](#ft15ar5arnet5x2)|0.543242|0.834655|0.025942|0.00735|0.934|
# |[FT15,AR5,ARnet5x4](#ft15ar5arnet5x4)|0.540241|0.821678|0.025050|0.00025|0.9099|
# |[FT15,AR5,ARnet5x8](#ft15ar5arnet5x8)|0.543424|0.796626|0.023877|0.0133|0.902|
# |[FT15,AR5,ARnet5x16](#ft15ar5arnet5x16)|0.584585|0.918353|0.029887|-0.0038|0.856|
# |[FT15,AR5,ARnet6x2](#ft15ar5arnet6x2)|0.539486|0.836184|0.026060|-0.0044|0.936|
# |[FT15,AR5,ARnet6x4](#ft15ar5arnet6x4)|0.583161|0.883186|0.028258|-0.0034|0.933|
# |[FT15,AR5,ARnet6x8](#ft15ar5arnet6x8)|0.561130|0.868202|0.027160|-0.00238|0.9305|
# |[FT15,AR5,ARnet6x16](#ft15ar5arnet6x16)|0.556449|0.812239|0.024528|-0.005497|0.8755|
# |[FT15,AR5,ARnet6x32](#ft15ar5arnet6x32)|0.578182|0.849315|0.026734|0.034|0.959|
# |[FT15,AR5,ARnet7x2](#ft15ar5arnet7x2)|0.536318|0.832604|0.025838|0.0097|0.9358|
# |[FT15,AR5,ARnet7x4](#ft15ar5arnet7x4)|0.561611|0.816421|0.024972|0.00032|0.912|
# |[FT15,AR5,ARnet7x8](#ft15ar5arnet7x8)|0.579560|0.842249|0.026364|0.00914|0.902|
# |[FT15,AR5,ARnet7x16](#ft15ar5arnet7x16)|1.095238|1.383907|0.066553|-0.08|0.975|
# |[FT15,AR5,ARnet8x2](#ft15ar5arnet8x2)|0.574629|0.844537|0.026617|0.00642|0.91|
# |[FT15,AR5,ARnet8x4](#ft15ar5arnet8x4)|0.542323|0.834610|0.026000|0.00383|0.936|
# |[FT15,AR5,ARnet8x8](#ft15ar5arnet8x8)|0.596112|0.876596|0.028250|-0.00087|0.91|
# |[FT15,AR5,ARnet16x2](#ft15ar5arnet16x2)|0.538644|0.835522|0.025994|0.0062|0.9359|
# |[FT15,AR5,ARnet16x4](#ft15ar5arnet16x4)|0.537406|0.833495|0.025872|0.00083|0.9357|
# |[FT15,AR5,ARnet16x8](#ft15ar5arnet16x8)|0.555139|0.840170|0.026161|0.00296|0.8857|
# |[FT15,AR5,ARnet32x16](#ft15ar5arnet32x16)|5.010028|5.087449|0.620839|-5.015|0.9909|
# |[FT50,AR30,ARnet3x16](#ft50ar30arnet3x16)|0.776222|0.975216|0.036671|-0.01|0.648|
# |[FT50,AR30,ARnet3x32](#ft50ar30arnet3x32)|1.199970|1.521781|0.081522|-0.048|<font color="red">0.539<font color="red">|
# |[FT50,AR30,ARnet8x16](#ft50ar30arnet8x16)|0.685994|0.941857|0.033213|0.0038|0.815|
# |[FT50,AR30,ARnet8x32](#ft50ar30arnet8x32)|4.686959|4.771277|0.571177|-4.741|0.972|
# |[FT50,AR30,ARnet16x16](#ft50ar30arnet16x16)|0.678415|0.931407|0.032465|0.0053|0.9183|
# |[FT50,AR30,ARnet32x16](#ft50ar30arnet32x16)|0.665016|0.924093|0.032052|-0.0136|0.907|
# |[FT50,AR5,ARnet32x16](#ft50ar5arnet32x16)|0.620467|0.884516|0.029424|0.00657|0.9042|

# %% [markdown]
# ## Import

# %%
import os
import sys
import logging
import multiprocessing
import pandas as pd
import numpy as np
import sqlalchemy
import exchange_calendars as xcals
from dotenv import load_dotenv

# import exchange_calendars as xcals
from datetime import datetime, timedelta

# import pytz
# import pandas as pd
# from IPython.display import display, HTML
from sqlalchemy import create_engine
from sqlalchemy.dialects.postgresql import insert, TEXT
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

from neuralprophet import NeuralProphet, set_log_level, set_random_seed
# Out:
# Importing plotly failed. Interactive plots will not work.
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# ## Init

# %%
random_seed = 7

# Disable logging messages unless there is an error
set_log_level("ERROR")

load_dotenv()  # take environment variables from .env.

module_path = os.getenv("LOCAL_AKSHARE_DEV_MODULE")
if module_path is not None and module_path not in sys.path:
    sys.path.insert(0, module_path)
import akshare as ak  # noqa: E402

print(ak.__version__)

DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")

# Create an engine instance
alchemyEngine = create_engine(
    f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}",
    pool_recycle=3600,
)

logger = logging.getLogger(__name__)
logger.setLevel(logging.ERROR)

file_handler = logging.FileHandler("etl.log")
console_handler = logging.StreamHandler()

# Step 4: Create a formatter
formatter = logging.Formatter("%(name)s - %(levelname)s - %(message)s")

# Step 5: Attach the formatter to the handlers
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)

# Step 6: Add the handlers to the logger
logger.addHandler(file_handler)
logger.addHandler(console_handler)

xshg = xcals.get_calendar("XSHG")
# Out:
# 1.13.16

# %% [markdown]
# ## Helper Functions

# %%
def predict(
    symbol, y_column, country=None, fourier_terms="auto", show_uncertainty=False
) -> (NeuralProphet, pd.DataFrame, pd.DataFrame):  # type: ignore
    return predict_generic(
        "fund_etf_daily_em", symbol, y_column, country, fourier_terms, show_uncertainty
    )


def predict_generic(
    table,
    symbol,
    y_column,
    country=None,
    fourier_terms="auto",
    show_uncertainty=False,
) -> (NeuralProphet, pd.DataFrame, pd.DataFrame):  # type: ignore
    query = f"SELECT * FROM {table} where symbol = '{symbol}' order by date"
    df = pd.read_sql(query, alchemyEngine, parse_dates=["date"])

    df = df.rename(
        columns={
            "date": "ds",
            y_column: "y",
        }
    )

    m = NeuralProphet(
        mcmc_samples=300 if show_uncertainty else 0,
        daily_seasonality=False,
        weekly_seasonality=False,
        yearly_seasonality=fourier_terms,
    )  # Prophet object can only be fit once. Instantiate a new object.
    if country is not None:
        m.add_country_holidays(country_name=country)
    m.fit(df)

    future = m.make_future_dataframe(periods=60)
    forecast = m.predict(future)

    return (m, df, forecast)

# %% [markdown]
# ## Univariate: Change_Rate

# %% [markdown]
# ### Load data from table

# %%
# load main TS
symbol = "930955"
query = f"""
    SELECT date DS, change_rate y 
    FROM index_daily_em_view 
    where symbol='{symbol}'
    order by DS
"""
df = pd.read_sql(query, alchemyEngine, parse_dates=["date"])

# Display the first few rows of the dataframe
df.head()
# Out:
#            ds     y
# 0  2020-02-10  0.00
# 1  2020-02-11  0.44
# 2  2020-02-12  0.42
# 3  2020-02-13 -0.71
# 4  2020-02-14  0.43

# %%
df.describe()

# %% [markdown]
# ### Trial 1 - Classic

# %% [markdown]
# #### Default

# %%
# The seed must be set each time before model creation
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape
# Out:
# ((905, 2), (100, 2))

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics
# Out:
# Finding best initial lr:   0%|          | 0/225 [00:00<?, ?it/s]
#       MAE_val  RMSE_val  Loss_val  RegLoss_val  epoch       MAE      RMSE  \
# 0    7.065539  8.385587  0.955930          0.0      0  4.108202  5.069713
# 1    5.479837  6.630581  0.711753          0.0      1  3.193249  4.031426
# 2    4.018025  4.984940  0.488754          0.0      2  2.518200  3.175875
# 3    2.843034  3.573823  0.315734          0.0      3  1.967695  2.427764
# 4    2.017914  2.484805  0.192968          0.0      4  1.511983  1.835232
# ..        ...       ...       ...          ...    ...       ...       ...
# 115  0.585814  0.871918  0.028430          0.0    115  0.719424  0.964524
# 116  0.584610  0.871496  0.028389          0.0    116  0.715569  0.947395
# 117  0.583739  0.870328  0.028316          0.0    117  0.718959  0.956856
# 118  0.584861  0.870807  0.028359          0.0    118  0.708119  0.947146
# 119  0.584736  0.870487  0.028346          0.0    119  0.719954  0.964818
#
#          Loss  RegLoss
# 0    0.389857      0.0
# 1    0.278213      0.0
# 2    0.198486      0.0
# 3    0.135018      0.0
# 4    0.087462      0.0
# ..        ...      ...
# 115  0.026201      0.0
# 116  0.025569      0.0
# 117  0.025908      0.0
# 118  0.025489      0.0
# 119  0.026127      0.0
#
# [120 rows x 9 columns]

# %%
# Access the trained model parameters
model_parameters = m.model.state_dict()

# If you want to print the parameters, you can iterate over the dictionary
for name, param in model_parameters.items():
    print(name, param)
# Out:
# trend.bias tensor([0.7407])
# trend.trend_k0 tensor([[[-0.6141]]])
# trend.trend_deltas tensor([[[0.7400, 0.8916, 0.2634, 0.8135, 0.4437, 0.9607, 0.4889, 0.5908,
#           0.4026, 0.8872, 0.5724]]])
# trend.trend_changepoints_t tensor([0.0000, 0.0727, 0.1455, 0.2182, 0.2909, 0.3636, 0.4364, 0.5091, 0.5818,
#         0.6545, 0.7273])
# seasonality.season_params.yearly tensor([[[ 0.0095,  0.0059,  0.0020,  0.0027, -0.0099,  0.0001, -0.0019,
#           -0.0105,  0.0088, -0.0075, -0.0005,  0.0031]]])

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=365)
forecast = m.predict(future)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/data/split.py:273: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
forecast
# Out:
#              ds     y     yhat1     trend  season_yearly
# 0    2020-02-10  0.00  0.040679 -0.066376       0.107054
# 1    2020-02-11  0.44  0.041271 -0.065776       0.107047
# 2    2020-02-12  0.42  0.041568 -0.065178       0.106746
# 3    2020-02-13 -0.71  0.041595 -0.064579       0.106174
# 4    2020-02-14  0.43  0.041335 -0.063981       0.105316
# ...         ...   ...       ...       ...            ...
# 1365 2025-08-14   NaN -0.064790 -0.109046       0.044256
# 1366 2025-08-15   NaN -0.057755 -0.109245       0.051490
# 1367 2025-08-18   NaN -0.039183 -0.109840       0.070657
# 1368 2025-08-19   NaN -0.034066 -0.110038       0.075972
# 1369 2025-08-20   NaN -0.029577 -0.110236       0.080659
#
# [1370 rows x 5 columns]

# %%
yearly_seasonality = forecast[['ds', 'season_yearly']]
print(yearly_seasonality)
# Out:
#              ds  season_yearly
# 0    2020-02-10       0.107054
# 1    2020-02-11       0.107047
# 2    2020-02-12       0.106746
# 3    2020-02-13       0.106174
# 4    2020-02-14       0.105316
# ...         ...            ...
# 1365 2025-08-14       0.044256
# 1366 2025-08-15       0.051490
# 1367 2025-08-18       0.070657
# 1368 2025-08-19       0.075972
# 1369 2025-08-20       0.080659
#
# [1370 rows x 2 columns]

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)
# Out:
# ERROR - (NP.plotly.plot_components) - plotly-resampler is not installed. Please install it to use the resampler.
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_forecast_plotly.py:410: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
m.plot_parameters()
# Out:
# ERROR - (NP.plotly.plot_parameters) - plotly-resampler is not installed. Please install it to use the resampler.
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:237: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:271: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:475: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:508: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %% [markdown]
# #### Imputation

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    impute_missing=True,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### n_changepoints=64

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    n_changepoints=64,
    weekly_seasonality=False,
    daily_seasonality=False,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### n_changepoints=128

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    n_changepoints=128,
    weekly_seasonality=False,
    daily_seasonality=False,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### Quantile

# %%
set_random_seed(random_seed)

confidence_level = 0.9

boundaries = round((1 - confidence_level) / 2, 2)
# NeuralProphet only accepts quantiles value in between 0 and 1
quantiles = [boundaries, confidence_level + boundaries]

m = NeuralProphet(
    quantiles=quantiles,
    weekly_seasonality=False,
    daily_seasonality=False,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### Conformal Forecast

# %%
set_random_seed(random_seed)

confidence_level = 0.9

boundaries = round((1 - confidence_level) / 2, 2)
# NeuralProphet only accepts quantiles value in between 0 and 1
quantiles = [boundaries, confidence_level + boundaries]

m = NeuralProphet(
    quantiles=quantiles,
    weekly_seasonality=False,
    daily_seasonality=False,
)

train_df, test_df = m.split_df(df, valid_p=1.0 / 16)
train_df, cal_df = m.split_df(train_df, valid_p=1.0 / 16)

train_df.shape, cal_df.shape, test_df.shape
# Out:
# ((885, 2), (58, 2), (62, 2))

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics
# Out:
# Finding best initial lr:   0%|          | 0/224 [00:00<?, ?it/s]
#        MAE_val   RMSE_val  Loss_val  RegLoss_val  epoch        MAE       RMSE  \
# 0    16.627422  16.704563  5.139360          0.0      0  12.981752  13.321748
# 1    13.257821  13.358927  3.571944          0.0      1  10.649820  11.007987
# 2     9.657036   9.866037  1.954800          0.0      2   8.197012   8.689247
# 3     5.621061   6.256266  0.905707          0.0      3   5.664538   6.438600
# 4     3.199273   3.693274  0.498300          0.0      4   3.471202   4.476577
# ..         ...        ...       ...          ...    ...        ...        ...
# 115   0.746238   1.057082  0.064444          0.0    115   0.715266   0.952198
# 116   0.747615   1.058325  0.064590          0.0    116   0.718122   0.956976
# 117   0.749939   1.060486  0.064801          0.0    117   0.717929   0.960855
# 118   0.748509   1.058799  0.064604          0.0    118   0.722981   0.963845
# 119   0.747731   1.060004  0.064700          0.0    119   0.718191   0.957127
#
#          Loss  RegLoss
# 0    3.213055      0.0
# 1    2.356146      0.0
# 2    1.546199      0.0
# 3    0.894321      0.0
# 4    0.456415      0.0
# ..        ...      ...
# 115  0.034756      0.0
# 116  0.034899      0.0
# 117  0.034910      0.0
# 118  0.035274      0.0
# 119  0.035074      0.0
#
# [120 rows x 9 columns]

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=365)
forecast = m.predict(future)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/data/split.py:273: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
forecast
# Out:
#              ds     y     yhat1  yhat1 5.0%  yhat1 95.0%     trend  \
# 0    2020-02-10  0.00 -0.160549   -1.042003     1.109105 -0.285431
# 1    2020-02-11  0.44 -0.156471   -1.049672     1.149662 -0.281583
# 2    2020-02-12  0.42 -0.152555   -1.059310     1.190113 -0.277735
# 3    2020-02-13 -0.71 -0.148773   -1.070765     1.230273 -0.273886
# 4    2020-02-14  0.43 -0.145140   -1.083984     1.269915 -0.270038
# ...         ...   ...       ...         ...          ...       ...
# 1365 2025-08-14   NaN  0.022483   -0.260288     0.467909  0.009122
# 1366 2025-08-15   NaN  0.029120   -0.235144     0.465530  0.009065
# 1367 2025-08-18   NaN  0.046999   -0.172983     0.470711  0.008893
# 1368 2025-08-19   NaN  0.052068   -0.157169     0.476318  0.008836
# 1369 2025-08-20   NaN  0.056604   -0.143959     0.483691  0.008779
#
#       season_yearly
# 0          0.124883
# 1          0.125112
# 2          0.125180
# 3          0.125114
# 4          0.124898
# ...             ...
# 1365       0.013361
# 1366       0.020055
# 1367       0.038105
# 1368       0.043232
# 1369       0.047826
#
# [1370 rows x 7 columns]

# %%
fake_forecast_hist = m.predict(df)

# %%
fake_forecast_hist
# Out:
#              ds     y     yhat1  yhat1 5.0%  yhat1 95.0%     trend  \
# 0    2020-02-10  0.00 -0.160549   -1.042003     1.109105 -0.285431
# 1    2020-02-11  0.44 -0.156471   -1.049672     1.149662 -0.281583
# 2    2020-02-12  0.42 -0.152555   -1.059310     1.190113 -0.277735
# 3    2020-02-13 -0.71 -0.148773   -1.070765     1.230273 -0.273886
# 4    2020-02-14  0.43 -0.145140   -1.083984     1.269915 -0.270038
# ...         ...   ...       ...         ...          ...       ...
# 1000 2024-03-21  0.02  0.152799   -0.766856     1.137946  0.038420
# 1001 2024-03-22 -1.00  0.153360   -0.747835     1.104627  0.038363
# 1002 2024-03-25 -0.19  0.155024   -0.687526     1.009634  0.038191
# 1003 2024-03-26  0.34  0.155565   -0.666966     0.980376  0.038133
# 1004 2024-03-27 -0.91  0.156030   -0.646708     0.952645  0.038076
#
#       season_yearly
# 0          0.124883
# 1          0.125112
# 2          0.125180
# 3          0.125114
# 4          0.124898
# ...             ...
# 1000       0.114379
# 1001       0.114998
# 1002       0.116833
# 1003       0.117432
# 1004       0.117954
#
# [1005 rows x 7 columns]

# %%
m.plot_components(
    fake_forecast_hist,
)
# Out:
# ERROR - (NP.plotly.plot_components) - plotly-resampler is not installed. Please install it to use the resampler.
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_forecast_plotly.py:410: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")
# Out:
# Mean difference: 0.017509414805701715, Standard deviation of difference: 0.9611085755704407

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)
# Out:
# ERROR - (NP.plotly.plot_components) - plotly-resampler is not installed. Please install it to use the resampler.
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_forecast_plotly.py:410: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
m.plot_parameters()
# Out:
# ERROR - (NP.plotly.plot_parameters) - plotly-resampler is not installed. Please install it to use the resampler.
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:237: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:271: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:475: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:508: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %% [markdown]
# ##### Naive

# %%
method = "naive"  # naive / cqr. ref: https://neuralprophet.com/how-to-guides/feature-guides/uncertainty_quantification.html
alpha = 1 - confidence_level

cfm_forecast_naive = m.conformal_predict(
    future,
    calibration_df=cal_df,
    alpha=alpha,
    method=method,
    plotting_backend="plotly",
    show_all_PI=True,
)

# %%
cfm_forecast_naive

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (cfm_forecast_naive["yhat1"] - cfm_forecast_naive["y"]).mean()
std_diff = (cfm_forecast_naive["yhat1"] - cfm_forecast_naive["y"]).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.highlight_nth_step_ahead_of_each_forecast(1).plot(
    cfm_forecast_naive, plotting_backend="plotly"
)

# %%
m.plot_parameters()

# %% [markdown]
# ##### CQR

# %%
method = "cqr"  # naive / cqr. ref: https://neuralprophet.com/how-to-guides/feature-guides/uncertainty_quantification.html
alpha = 1 - confidence_level

cfm_forecast_cqr = m.conformal_predict(
    future,
    calibration_df=cal_df,
    alpha=alpha,
    method=method,
    plotting_backend="plotly",
    show_all_PI=True,
)

# %%
cfm_forecast_cqr

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (cfm_forecast_cqr["yhat1"] - cfm_forecast_cqr["y"]).mean()
std_diff = (cfm_forecast_cqr["yhat1"] - cfm_forecast_cqr["y"]).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.highlight_nth_step_ahead_of_each_forecast(1).plot(
    cfm_forecast_cqr, plotting_backend="plotly"
)

# %%
m.plot_parameters()

# %% [markdown]
# #### Seasonality_Reg=0.1

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # Smaller values (~0.1-1) allow the model to fit larger seasonal fluctuations,
    # larger values (~1-100) dampen the seasonality. default: None, no regularization
    seasonality_reg=0.1,
    # fourier terms, default 10
    # yearly_seasonality=11,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### Seasonality_Reg=0.2

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # Smaller values (~0.1-1) allow the model to fit larger seasonal fluctuations,
    # larger values (~1-100) dampen the seasonality. default: None, no regularization
    seasonality_reg=0.2,
    # fourier terms, default 10
    # yearly_seasonality=11,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### Fourier terms=12

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=12,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### Fourier terms=15

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=15,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### Fourier terms=20 (!)

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=20,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### Fourier terms=30

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=30,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### Fourier terms=50

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=50,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### Fourier terms=100

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=100,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### SR01+FT30

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # Smaller values (~0.1-1) allow the model to fit larger seasonal fluctuations,
    # larger values (~1-100) dampen the seasonality. default: None, no regularization
    seasonality_reg=0.1,
    # fourier terms, default 10
    yearly_seasonality=30,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### SR01+FT100

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # Smaller values (~0.1-1) allow the model to fit larger seasonal fluctuations,
    # larger values (~1-100) dampen the seasonality. default: None, no regularization
    seasonality_reg=0.1,
    # fourier terms, default 10
    yearly_seasonality=100,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %%
confidence_level = 0.9

boundaries = round((1 - confidence_level) / 2, 2)
# NeuralProphet only accepts quantiles value in between 0 and 1
quantiles = [boundaries, confidence_level + boundaries]

m = NeuralProphet(
    quantiles=quantiles,
    weekly_seasonality=False,
    daily_seasonality=False,
    # Smaller values (~0.1-1) allow the model to fit larger seasonal fluctuations,
    # larger values (~1-100) dampen the seasonality. default: None, no regularization
    seasonality_reg=0.1,
    # fourier terms, default 10
    yearly_seasonality=50,
)

train_df, test_df = m.split_df(df, valid_p=1.0 / 16)
train_df, cal_df = m.split_df(train_df, valid_p=1.0 / 16)

train_df.shape, cal_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %%
method = "naive"  # naive / cqr. ref: https://neuralprophet.com/how-to-guides/feature-guides/uncertainty_quantification.html
alpha = 1 - confidence_level

cfm_forecast_naive = m.conformal_predict(
    future,
    calibration_df=cal_df,
    alpha=alpha,
    method=method,
    plotting_backend="plotly",
    show_all_PI=True,
)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (cfm_forecast_naive["yhat1"] - cfm_forecast_naive["y"]).mean()
std_diff = (cfm_forecast_naive["yhat1"] - cfm_forecast_naive["y"]).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.highlight_nth_step_ahead_of_each_forecast(1).plot(
    cfm_forecast_naive, plotting_backend="plotly"
)

# %% [markdown]
# ### Trial 2 - AR

# %% [markdown]
# #### n_lag=3

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=3,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### n_lag=5

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### n_lag=10

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=10,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### n_lag=30

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=30,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### AR5+Reg0001

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # how much sparsity to induce in the AR-coefficients.
    # Large values (~1-100) will limit the number of nonzero coefficients dramatically.
    # Small values (~0.001-1.0) will allow more non-zero coefficients. 
    # default: 0 no regularization of coefficients.
    ar_reg=0.001,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### AR5+Reg001

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # how much sparsity to induce in the AR-coefficients.
    # Large values (~1-100) will limit the number of nonzero coefficients dramatically.
    # Small values (~0.001-1.0) will allow more non-zero coefficients. 
    # default: 0 no regularization of coefficients.
    ar_reg=0.01,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### AR5+Reg2

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # how much sparsity to induce in the AR-coefficients.
    # Large values (~1-100) will limit the number of nonzero coefficients dramatically.
    # Small values (~0.001-1.0) will allow more non-zero coefficients. 
    # default: 0 no regularization of coefficients.
    ar_reg=2.,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# ### Trial C1: FT + AR

# %% [markdown]
# #### FT15+AR5

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape
# Out:
# ((968, 2), (112, 2))

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics
# Out:
# Finding best initial lr:   0%|          | 0/225 [00:00<?, ?it/s]
#        MAE_val   RMSE_val  Loss_val  RegLoss_val  epoch        MAE       RMSE  \
# 0    17.797405  20.139372  2.588991          0.0      0  11.523213  14.108348
# 1    12.123075  13.921045  1.716084          0.0      1   7.841274   9.720254
# 2     8.051757   9.245188  1.090255          0.0      2   5.105577   6.372594
# 3     5.248906   5.976878  0.659425          0.0      3   3.398646   4.254410
# 4     3.592021   4.037699  0.405381          0.0      4   2.269152   2.794555
# ..         ...        ...       ...          ...    ...        ...        ...
# 105   0.526869   0.807919  0.024424          0.0    105   0.707060   0.934380
# 106   0.524988   0.807207  0.024372          0.0    106   0.710104   0.947607
# 107   0.525270   0.807615  0.024389          0.0    107   0.688594   0.907444
# 108   0.526331   0.808551  0.024440          0.0    108   0.708036   0.929689
# 109   0.524882   0.806963  0.024343          0.0    109   0.700995   0.926027
#
#          Loss  RegLoss
# 0    1.268221      0.0
# 1    0.815903      0.0
# 2    0.489777      0.0
# 3    0.286363      0.0
# 4    0.160108      0.0
# ..        ...      ...
# 105  0.024428      0.0
# 106  0.025564      0.0
# 107  0.023461      0.0
# 108  0.024284      0.0
# 109  0.023791      0.0
#
# [110 rows x 9 columns]

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/data/split.py:273: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, future_df])

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")
# Out:
# Mean difference: -0.00108206889785339, Standard deviation of difference: 0.9309481241321214

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_forecast_plotly.py:100: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ds = fcst["ds"].dt.to_pydatetime()

# %%
m.plot_components(
    forecast,
)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_forecast_plotly.py:410: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
m.plot_parameters()
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:237: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:271: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:475: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:508: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %% [markdown]
# #### FT50+AR5

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=50,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape
# Out:
# ((968, 2), (112, 2))

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics
# Out:
# Finding best initial lr:   0%|          | 0/225 [00:00<?, ?it/s]
#       MAE_val  RMSE_val  Loss_val  RegLoss_val  epoch       MAE      RMSE  \
# 0    5.493071  6.659608  0.707508          0.0      0  5.064016  6.199229
# 1    4.320359  5.374653  0.532464          0.0      1  3.738872  4.722502
# 2    3.391613  4.318614  0.393956          0.0      2  2.597831  3.443562
# 3    2.620144  3.398640  0.279815          0.0      3  1.940332  2.610776
# 4    2.075667  2.661086  0.200011          0.0      4  1.559380  2.066994
# ..        ...       ...       ...          ...    ...       ...       ...
# 105  0.624484  0.883009  0.029272          0.0    105  0.699937  0.907658
# 106  0.622765  0.880813  0.029124          0.0    106  0.684838  0.895095
# 107  0.621958  0.881983  0.029159          0.0    107  0.668270  0.878047
# 108  0.620005  0.880594  0.029056          0.0    108  0.681351  0.895432
# 109  0.621913  0.880796  0.029079          0.0    109  0.664013  0.865880
#
#          Loss  RegLoss
# 0    0.479141      0.0
# 1    0.329647      0.0
# 2    0.207585      0.0
# 3    0.137821      0.0
# 4    0.097051      0.0
# ..        ...      ...
# 105  0.023393      0.0
# 106  0.022271      0.0
# 107  0.021632      0.0
# 108  0.022703      0.0
# 109  0.021592      0.0
#
# [110 rows x 9 columns]

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT50+AR10

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=10,
    # fourier terms, default 10
    yearly_seasonality=50,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT50+AR30

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=30,
    # fourier terms, default 10
    yearly_seasonality=50,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# ### Trial 3 - ARnet

# %% [markdown]
# #### 3 x 16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # --- array of hidden layer dimensions of the AR-Net. Specifies number of hidden layers (number of entries) and layer dimension (list entry)
    ar_layers=[16]*3,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
# m.highlight_nth_step_ahead_of_each_forecast(None)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### 3 x 32

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # --- array of hidden layer dimensions of the AR-Net. Specifies number of hidden layers (number of entries) and layer dimension (list entry)
    ar_layers=[32,32,32],
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
# m.highlight_nth_step_ahead_of_each_forecast(None)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### 8 x 16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # --- array of hidden layer dimensions of the AR-Net. Specifies number of hidden layers (number of entries) and layer dimension (list entry)
    ar_layers=[16]*8,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
# m.highlight_nth_step_ahead_of_each_forecast(None)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %% [markdown]
# ### Trial C2: AR + ARnet

# %% [markdown]
# #### AR5 + ARnet32x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    ar_layers=[16] * 32,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### AR5 + ARnet3x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    ar_layers=[16] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# ### Trial C3: FT + ARnet

# %% [markdown]
# #### FT5 + ARnet3x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=5,
    ar_layers=[16] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT12 + ARnet3x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=12,
    ar_layers=[16] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15 + ARnet3x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[16] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT20 + ARnet3x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=20,
    ar_layers=[16] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT30 + ARnet3x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=30,
    ar_layers=[16] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=50,
    ar_layers=[16] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15 + ARnet32x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[16] * 32,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# ### Trial C4: FT + AR + ARnet

# %% [markdown]
# #### FT15,AR5,ARnet2x4

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[4] * 2,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet2x8

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[8] * 2,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet2x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[16] * 2,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet3x4

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[4] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet3x8

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[8] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet3x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[16] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet3x32

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[32] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet4x2

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[2] * 4,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet4x4

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[4] * 4,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape
# Out:
# ((968, 2), (112, 2))

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics
# Out:
# Finding best initial lr:   0%|          | 0/225 [00:00<?, ?it/s]
#       MAE_val  RMSE_val  Loss_val  RegLoss_val  epoch       MAE      RMSE  \
# 0    3.587967  4.584080  0.421860          0.0      0  3.635068  4.453643
# 1    2.183571  2.950723  0.225532          0.0      1  2.620447  3.228643
# 2    1.643062  2.255796  0.146140          0.0      2  1.849365  2.300441
# 3    1.011409  1.497030  0.067824          0.0      3  1.293822  1.627048
# 4    1.020312  1.451083  0.065889          0.0      4  0.976489  1.239068
# ..        ...       ...       ...          ...    ...       ...       ...
# 105  0.534155  0.798707  0.023811          0.0    105  0.684443  0.899668
# 106  0.533041  0.797852  0.023767          0.0    106  0.697235  0.904126
# 107  0.534252  0.798092  0.023790          0.0    107  0.694852  0.909969
# 108  0.532713  0.798148  0.023775          0.0    108  0.702701  0.911949
# 109  0.531110  0.795895  0.023643          0.0    109  0.686934  0.901063
#
#          Loss  RegLoss
# 0    0.328413      0.0
# 1    0.203503      0.0
# 2    0.123400      0.0
# 3    0.069556      0.0
# 4    0.043238      0.0
# ..        ...      ...
# 105  0.022936      0.0
# 106  0.023359      0.0
# 107  0.023274      0.0
# 108  0.023707      0.0
# 109  0.023118      0.0
#
# [110 rows x 9 columns]

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/data/split.py:273: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")
# Out:
# Mean difference: -0.002696929628603931, Standard deviation of difference: 0.9110396517686848

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_forecast_plotly.py:100: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
m.plot_components(
    forecast,
)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_forecast_plotly.py:410: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
m.plot_parameters()
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:237: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:271: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:475: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/plot_model_parameters_plotly.py:508: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %% [markdown]
# #### FT15,AR5,ARnet4x8

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[8] * 4,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet4x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[16] * 4,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet5x2

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[2] * 5,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet5x4

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[4] * 5,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet5x8

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[8] * 5,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet5x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[16] * 5,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet6x2

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[2] * 6,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet6x4

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[4] * 6,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet6x8

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[8] * 6,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet6x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[16] * 6,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet6x32

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[32] * 6,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet7x2

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[2] * 7,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet7x4

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[4] * 7,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet7x8

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[8] * 7,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet7x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[16] * 7,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet8x2

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[2] * 8,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet8x4

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[4] * 8,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape
# Out:
# ((968, 2), (112, 2))

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics
# Out:
# Finding best initial lr:   0%|          | 0/225 [00:00<?, ?it/s]
#       MAE_val  RMSE_val  Loss_val  RegLoss_val  epoch       MAE      RMSE  \
# 0    6.767679  7.649721  0.893947          0.0      0  4.109210  5.040415
# 1    5.807692  6.595535  0.746510          0.0      1  3.394076  4.177386
# 2    4.867329  5.546720  0.603070          0.0      2  2.759565  3.432643
# 3    3.965529  4.487700  0.464952          0.0      3  2.225182  2.768194
# 4    3.052890  3.425764  0.325467          0.0      4  1.715488  2.154058
# ..        ...       ...       ...          ...    ...       ...       ...
# 105  0.544437  0.836281  0.026087          0.0    105  0.695264  0.919019
# 106  0.543215  0.835296  0.026026          0.0    106  0.692162  0.913239
# 107  0.542378  0.835463  0.026027          0.0    107  0.702095  0.922547
# 108  0.542411  0.835116  0.026002          0.0    108  0.690192  0.912978
# 109  0.542323  0.834610  0.026000          0.0    109  0.697806  0.914693
#
#          Loss  RegLoss
# 0    0.391592      0.0
# 1    0.302333      0.0
# 2    0.229076      0.0
# 3    0.167962      0.0
# 4    0.111957      0.0
# ..        ...      ...
# 105  0.023825      0.0
# 106  0.023679      0.0
# 107  0.024026      0.0
# 108  0.023669      0.0
# 109  0.023846      0.0
#
# [110 rows x 9 columns]

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/data/split.py:273: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, future_df])

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")
# Out:
# Mean difference: 0.0038299242536598273, Standard deviation of difference: 0.9360763332613427

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet8x8

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[8] * 8,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape
# Out:
# ((968, 2), (112, 2))

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics
# Out:
# Finding best initial lr:   0%|          | 0/225 [00:00<?, ?it/s]
#       MAE_val  RMSE_val  Loss_val  RegLoss_val  epoch       MAE      RMSE  \
# 0    7.612294  8.488541  1.022336          0.0      0  6.272789  7.465715
# 1    5.069661  6.080718  0.645221          0.0      1  3.899079  4.735395
# 2    3.522124  4.384143  0.409557          0.0      2  2.966455  3.616067
# 3    2.694052  3.396109  0.286151          0.0      3  2.531565  3.088616
# 4    2.104655  2.728022  0.206064          0.0      4  2.144896  2.640099
# ..        ...       ...       ...          ...    ...       ...       ...
# 105  0.595554  0.877072  0.028286          0.0    105  0.675051  0.889741
# 106  0.595040  0.876481  0.028253          0.0    106  0.702103  0.917358
# 107  0.597212  0.876791  0.028255          0.0    107  0.677309  0.891338
# 108  0.596966  0.877132  0.028270          0.0    108  0.679606  0.895882
# 109  0.596112  0.876596  0.028250          0.0    109  0.679397  0.892248
#
#          Loss  RegLoss
# 0    0.652750      0.0
# 1    0.361700      0.0
# 2    0.247580      0.0
# 3    0.194159      0.0
# 4    0.151800      0.0
# ..        ...      ...
# 105  0.022293      0.0
# 106  0.024093      0.0
# 107  0.022461      0.0
# 108  0.022629      0.0
# 109  0.022409      0.0
#
# [110 rows x 9 columns]

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/data/split.py:273: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, future_df])

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")
# Out:
# Mean difference: -0.0008695635216258427, Standard deviation of difference: 0.9102413972634641

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet16x2

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[2] * 16,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape
# Out:
# ((968, 2), (112, 2))

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics
# Out:
# Finding best initial lr:   0%|          | 0/225 [00:00<?, ?it/s]
#       MAE_val  RMSE_val  Loss_val  RegLoss_val  epoch       MAE      RMSE  \
# 0    4.995636  5.835915  0.631330          0.0      0  3.687903  4.544473
# 1    4.059750  4.672578  0.485985          0.0      1  2.910138  3.592424
# 2    3.590190  3.955674  0.406652          0.0      2  2.289933  2.865628
# 3    3.001579  3.214818  0.314584          0.0      3  1.714895  2.136917
# 4    2.109191  2.262581  0.181832          0.0      4  1.299265  1.599543
# ..        ...       ...       ...          ...    ...       ...       ...
# 105  0.535281  0.832622  0.025831          0.0    105  0.710302  0.932656
# 106  0.537833  0.833734  0.025882          0.0    106  0.708288  0.931302
# 107  0.537663  0.834971  0.025974          0.0    107  0.692740  0.911142
# 108  0.537829  0.835881  0.026025          0.0    108  0.695068  0.909328
# 109  0.538644  0.835522  0.025994          0.0    109  0.695053  0.919577
#
#          Loss  RegLoss
# 0    0.318585      0.0
# 1    0.236002      0.0
# 2    0.166585      0.0
# 3    0.107926      0.0
# 4    0.068087      0.0
# ..        ...      ...
# 105  0.024350      0.0
# 106  0.024292      0.0
# 107  0.023778      0.0
# 108  0.023683      0.0
# 109  0.023748      0.0
#
# [110 rows x 9 columns]

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/data/split.py:273: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, future_df])

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")
# Out:
# Mean difference: 0.006240507660625134, Standard deviation of difference: 0.9358791249018558

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet16x4

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[4] * 16,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape
# Out:
# ((968, 2), (112, 2))

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics
# Out:
# Finding best initial lr:   0%|          | 0/225 [00:00<?, ?it/s]
#       MAE_val  RMSE_val  Loss_val  RegLoss_val  epoch       MAE      RMSE  \
# 0    6.480913  7.318601  0.849542          0.0      0  3.973540  4.846451
# 1    5.279675  5.996632  0.666209          0.0      1  3.151234  3.873161
# 2    4.081556  4.683947  0.484692          0.0      2  2.469233  3.084419
# 3    3.026931  3.480378  0.324576          0.0      3  1.875141  2.340024
# 4    2.333882  2.585323  0.217987          0.0      4  1.417062  1.783717
# ..        ...       ...       ...          ...    ...       ...       ...
# 105  0.538833  0.834895  0.025948          0.0    105  0.689634  0.900528
# 106  0.537675  0.834380  0.025914          0.0    106  0.696747  0.924988
# 107  0.537466  0.833657  0.025869          0.0    107  0.720384  0.946083
# 108  0.536975  0.833553  0.025861          0.0    108  0.704290  0.926944
# 109  0.537406  0.833495  0.025872          0.0    109  0.702434  0.929097
#
#          Loss  RegLoss
# 0    0.372708      0.0
# 1    0.274736      0.0
# 2    0.196846      0.0
# 3    0.127990      0.0
# 4    0.079864      0.0
# ..        ...      ...
# 105  0.023615      0.0
# 106  0.024012      0.0
# 107  0.024633      0.0
# 108  0.024077      0.0
# 109  0.024358      0.0
#
# [110 rows x 9 columns]

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/data/split.py:273: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, future_df])

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")
# Out:
# Mean difference: 0.0008327941538017448, Standard deviation of difference: 0.9357131309445245

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet16x8

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[8] * 16,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape
# Out:
# ((968, 2), (112, 2))

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics
# Out:
# Finding best initial lr:   0%|          | 0/225 [00:00<?, ?it/s]
#       MAE_val  RMSE_val  Loss_val  RegLoss_val  epoch       MAE      RMSE  \
# 0    3.847147  4.740748  0.456445          0.0      0  3.675504  4.552569
# 1    2.135926  2.794343  0.211706          0.0      1  2.605045  3.214664
# 2    1.801147  2.453053  0.168143          0.0      2  1.895187  2.372173
# 3    1.157231  1.575555  0.078389          0.0      3  1.594488  2.003892
# 4    1.035279  1.461961  0.068399          0.0      4  1.410146  1.770747
# ..        ...       ...       ...          ...    ...       ...       ...
# 105  0.554025  0.842511  0.026174          0.0    105  0.687749  0.897780
# 106  0.555308  0.842730  0.026210          0.0    106  0.668717  0.875968
# 107  0.554614  0.843520  0.026299          0.0    107  0.684460  0.893135
# 108  0.552258  0.837472  0.025991          0.0    108  0.661559  0.869914
# 109  0.555139  0.840170  0.026161          0.0    109  0.654499  0.861055
#
#          Loss  RegLoss
# 0    0.321508      0.0
# 1    0.203479      0.0
# 2    0.130806      0.0
# 3    0.099095      0.0
# 4    0.080192      0.0
# ..        ...      ...
# 105  0.023567      0.0
# 106  0.022350      0.0
# 107  0.023298      0.0
# 108  0.021912      0.0
# 109  0.021518      0.0
#
# [110 rows x 9 columns]

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jx/.pyenv/versions/3.12.2/envs/venv_3.12.2/lib/python3.12/site-packages/neuralprophet/data/split.py:273: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, future_df])

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")
# Out:
# Mean difference: 0.00295960909406715, Standard deviation of difference: 0.8856799829813067

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT15,AR5,ARnet32x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=15,
    ar_layers=[16] * 32,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT50,AR30,ARnet3x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=30,
    # fourier terms, default 10
    yearly_seasonality=50,
    ar_layers=[16] * 3,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT50,AR30,ARnet3x32

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # --- array of hidden layer dimensions of the AR-Net. Specifies number of hidden layers (number of entries) and layer dimension (list entry)
    ar_layers=[32] * 3,
    n_lags=30,
    # --- fourier terms, default 10
    yearly_seasonality=50,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
# m.highlight_nth_step_ahead_of_each_forecast(None)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT50,AR30,ARnet8x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # --- array of hidden layer dimensions of the AR-Net. Specifies number of hidden layers (number of entries) and layer dimension (list entry)
    ar_layers=[16] * 8,
    n_lags=30,
    yearly_seasonality=50,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT50,AR30,ARnet8x32

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    # --- array of hidden layer dimensions of the AR-Net. Specifies number of hidden layers (number of entries) and layer dimension (list entry)
    ar_layers=[32] * 8,
    n_lags=30,
    # --- fourier terms, default 10
    yearly_seasonality=50,
)

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
# m.highlight_nth_step_ahead_of_each_forecast(None)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT50,AR30,ARnet16x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=30,
    # fourier terms, default 10
    yearly_seasonality=50,
    ar_layers=[16] * 16,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT50,AR30,ARnet32x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=30,
    # fourier terms, default 10
    yearly_seasonality=50,
    ar_layers=[16] * 32,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()

# %% [markdown]
# #### FT50,AR5,ARnet32x16

# %%
set_random_seed(random_seed)

m = NeuralProphet(
    weekly_seasonality=False,
    daily_seasonality=False,
    n_lags=5,
    # fourier terms, default 10
    yearly_seasonality=50,
    ar_layers=[16] * 32,
)

# m = m.add_country_holidays("CN")

train_df, test_df = m.split_df(
    df,
    valid_p=1.0 / 10,
)

train_df.shape, test_df.shape

# %%
metrics = m.fit(
    train_df,
    validation_df=test_df,
    progress=None,
)
metrics

# %%
future = m.make_future_dataframe(df, n_historic_predictions=True, periods=100)
forecast = m.predict(future)

# %%
# calculate the mean and standard deviation for the difference of 2 columns, 'yhat1' minus 'y', where ID = symbol for the dataframe cfm_forecast.
mean_diff = (
    forecast["yhat1"]
    - forecast["y"]
).mean()
std_diff = (
    forecast["yhat1"]
    - forecast["y"]
).std()
print(f"Mean difference: {mean_diff}, Standard deviation of difference: {std_diff}")

# %%
m.set_plotting_backend("plotly")
m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot(forecast)

# %%
m.plot_components(
    forecast,
)

# %%
m.plot_parameters()
