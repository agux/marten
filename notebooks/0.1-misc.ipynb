# %%
import logging

# %%
lg = logging.getLogger(__name__)
lg.handlers
# Out:
# []

# %%
l = [1]
if len(l) > 0:
    print("hhh")
# Out:
# hhh

# %%
l = ['a', 'cbd', 'zzzz', 'asodfhuapwoerfhn']
l.sort(key=len, reverse=True)

# %%
print(l)
# Out:
# ['asodfhuapwoerfhn', 'zzzz', 'cbd', 'a']

# %%
import pandas as pd

# %%
pd.read_csv("/Users/jx/Downloads/k.csv", encoding="gbk")
# Out:
#               1          2          3          4      5       6       7  \
# 0      2015/2/9  28.800000  28.756878  27.829555  28.63   99.91  103.98
# 1     2015/2/10  28.630000  29.435024  28.499700  28.75  102.54  103.06
# 2     2015/2/11  26.470710  26.470710  26.176691  26.44  102.39     104
# 3     2015/2/12  26.389094  26.389094  25.773367  25.80  103.41   102.8
# 4     2015/2/13  24.286958  24.286958  22.810473  23.41  103.55  104.61
# ...         ...        ...        ...        ...    ...     ...     ...
# 2405  2025/1/10  18.100000  18.310000  17.780000  18.05   98.93   98.93
# 2406  2025/1/13  18.710000  19.460000  18.710000  18.76  96.405  98.219
# 2407  2025/1/14  18.770000  19.790000  18.280000  19.48  97.066  97.463
# 2408  2025/1/15  19.480000  19.480000  18.600000  18.77  97.066  97.463
# 2409  2025/1/16  18.820000  19.450000  18.580000  18.86  95.936  95.936
#
#            8       9     10  ... Unnamed: 77 Unnamed: 78 Unnamed: 79  \
# 0      99.91  103.98    NaN  ...         NaN         NaN         NaN
# 1      101.3  103.06    NaN  ...         NaN         NaN         NaN
# 2     102.39     104    NaN  ...         NaN         NaN         NaN
# 3     101.37  105.45    NaN  ...         NaN         NaN         NaN
# 4     103.55   104.9    NaN  ...         NaN         NaN         NaN
# ...      ...     ...    ...  ...         ...         ...         ...
# 2405  96.035  97.471  18.71  ...       22.93       23.07        19.8
# 2406  96.405  98.219   19.6  ...       24.06       24.52       20.03
# 2407  94.837  95.387  19.83  ...          24       25.35       20.48
# 2408  94.837  95.387  20.55  ...       24.67       25.25       20.48
# 2409  93.011  94.779  19.78  ...       24.73       25.65       20.29
#
#      Unnamed: 80 Unnamed: 81 Unnamed: 82 Unnamed: 83 Unnamed: 84 Unnamed: 85  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 2405       19.98       19.04       19.15       33.88       33.67       35.28
# 2406       20.83       20.03       20.22       37.52       37.93       36.27
# 2407       20.86       19.64       20.37       36.40       39.29       34.96
# 2408       20.86       19.64       20.37       38.72       38.83       37.58
# 2409       20.57       19.91       20.14       37.51       39.99       37.51
#
#      Unnamed: 86
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2405       35.61
# 2406       37.02
# 2407       39.29
# 2408       38.01
# 2409       39.63
#
# [2410 rows x 87 columns]

# %%
l = []

def func(l):
    l.append(["2", "3"])

print(l)
func(l)
print(l)
# Out:
# []
# [['2', '3']]

# %%
import pandas as pd
import numpy as np

# Define start and end dates
start_date = "2000-01-01"
end_date = "2025-02-01"

# Generate date range
date_range = pd.date_range(start=start_date, end=end_date, freq="B")
# Set seed for reproducibility
np.random.seed(0)

# Generate random data
val1 = np.random.randn(len(date_range))
val2 = np.random.rand(len(date_range)) * 100

# Create DataFrame
df = pd.DataFrame({"Date": date_range, "val1": val1, "val2": val2})

# %%
df
# Out:
#            Date      val1       val2
# 0    2000-01-03  1.764052  41.675662
# 1    2000-01-04  0.400157  60.863386
# 2    2000-01-05  0.978738  15.004428
# 3    2000-01-06  2.240893  84.454948
# 4    2000-01-07  1.867558  62.106611
# ...         ...       ...        ...
# 6540 2025-01-27  0.398010  65.787646
# 6541 2025-01-28 -0.222363  91.151828
# 6542 2025-01-29  0.742029  93.803356
# 6543 2025-01-30 -2.405761  35.804058
# 6544 2025-01-31  0.742540  93.322294
#
# [6545 rows x 3 columns]

# %%
def modify_df(df):
    df = df[['Date', 'val1']].copy()

modify_df(df)

df
# Out:
#            Date      val1       val2
# 0    2000-01-03  1.764052  41.675662
# 1    2000-01-04  0.400157  60.863386
# 2    2000-01-05  0.978738  15.004428
# 3    2000-01-06  2.240893  84.454948
# 4    2000-01-07  1.867558  62.106611
# ...         ...       ...        ...
# 6540 2025-01-27  0.398010  65.787646
# 6541 2025-01-28 -0.222363  91.151828
# 6542 2025-01-29  0.742029  93.803356
# 6543 2025-01-30 -2.405761  35.804058
# 6544 2025-01-31  0.742540  93.322294
#
# [6545 rows x 3 columns]

# %%
from neuralprophet.event_utils import get_all_holidays
np_holidays = get_all_holidays(years=[2024], country="CN")

# %%
np_holidays
# Out:
# defaultdict(list,
#             {'元旦': [Timestamp('2024-01-01 00:00:00')],
#              '春节': [Timestamp('2024-02-10 00:00:00'),
#               Timestamp('2024-02-11 00:00:00'),
#               Timestamp('2024-02-12 00:00:00')],
#              '劳动节': [Timestamp('2024-05-01 00:00:00')],
#              '国庆节': [Timestamp('2024-10-01 00:00:00'),
#               Timestamp('2024-10-02 00:00:00'),
#               Timestamp('2024-10-03 00:00:00')],
#              '清明节': [Timestamp('2024-04-04 00:00:00')],
#              '端午节': [Timestamp('2024-06-10 00:00:00')],
#              '中秋节': [Timestamp('2024-09-17 00:00:00')],
#              '休息日（2024-02-04日起取代）': [Timestamp('2024-02-15 00:00:00')],
#              '休息日（2024-02-18日起取代）': [Timestamp('2024-02-16 00:00:00')],
#              '休息日（2024-04-07日起取代）': [Timestamp('2024-04-05 00:00:00')],
#              '休息日（2024-04-28日起取代）': [Timestamp('2024-05-02 00:00:00')],
#              '休息日（2024-05-11日起取代）': [Timestamp('2024-05-03 00:00:00')],
#              '休息日（2024-09-14日起取代）': [Timestamp('2024-09-16 00:00:00')],
#              '休息日（2024-09-29日起取代）': [Timestamp('2024-10-04 00:00:00')],
#              '休息日（2024-10-12日起取代）': [Timestamp('2024-10-07 00:00:00')]})

# %%
type(next(iter(np_holidays.values()))[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
import datetime

# 判断 2018年4月30号 是不是节假日
from chinese_calendar import is_holiday, is_workday

april_last = datetime.date(2018, 4, 30)
assert is_workday(april_last) is False
assert is_holiday(april_last) is True

# 或者在判断的同时，获取节日名
import chinese_calendar as calendar  # 也可以这样 import

on_holiday, holiday_name = calendar.get_holiday_detail(april_last)
assert on_holiday is True
assert holiday_name == calendar.Holiday.labour_day.value

# 还能判断法定节假日是不是调休
import chinese_calendar

assert chinese_calendar.is_in_lieu(datetime.date(2006, 2, 1)) is False
assert chinese_calendar.is_in_lieu(datetime.date(2006, 2, 2)) is True

# %%
import chinese_calendar as calendar
d = datetime.date(2025, 1, 27)
print(calendar.is_holiday(d))
print(calendar.get_holiday_detail(d))
# Out:
# False
# (False, None)

# %%
import holidays
cn_holidays = holidays.country_holidays(country='CN', years=[2023, 2024, 2025])
# Iterate over the holidays and print them
for date, name in sorted(cn_holidays.items()):
    print(date, name, type(date))
# Out:
# 2023-01-01 元旦 <class 'datetime.date'>
# 2023-01-02 元旦（观察日） <class 'datetime.date'>
# 2023-01-22 春节 <class 'datetime.date'>
# 2023-01-23 春节 <class 'datetime.date'>
# 2023-01-24 春节 <class 'datetime.date'>
# 2023-01-25 春节（观察日） <class 'datetime.date'>
# 2023-01-26 休息日（2023-01-28日起取代） <class 'datetime.date'>
# 2023-01-27 休息日（2023-01-29日起取代） <class 'datetime.date'>
# 2023-04-05 清明节 <class 'datetime.date'>
# 2023-05-01 劳动节 <class 'datetime.date'>
# 2023-05-02 休息日（2023-04-23日起取代） <class 'datetime.date'>
# 2023-05-03 休息日（2023-05-06日起取代） <class 'datetime.date'>
# 2023-06-22 端午节 <class 'datetime.date'>
# 2023-06-23 休息日（2023-06-25日起取代） <class 'datetime.date'>
# 2023-09-29 中秋节 <class 'datetime.date'>
# 2023-10-01 国庆节 <class 'datetime.date'>
# 2023-10-02 国庆节 <class 'datetime.date'>
# 2023-10-03 国庆节 <class 'datetime.date'>
# 2023-10-04 国庆节（观察日） <class 'datetime.date'>
# 2023-10-05 休息日（2023-10-07日起取代） <class 'datetime.date'>
# 2023-10-06 休息日（2023-10-08日起取代） <class 'datetime.date'>
# 2024-01-01 元旦 <class 'datetime.date'>
# 2024-02-10 春节 <class 'datetime.date'>
# 2024-02-11 春节 <class 'datetime.date'>
# 2024-02-12 春节 <class 'datetime.date'>
# 2024-02-13 春节（观察日） <class 'datetime.date'>
# 2024-02-14 春节（观察日） <class 'datetime.date'>
# 2024-02-15 休息日（2024-02-04日起取代） <class 'datetime.date'>
# 2024-02-16 休息日（2024-02-18日起取代） <class 'datetime.date'>
# 2024-04-04 清明节 <class 'datetime.date'>
# 2024-04-05 休息日（2024-04-07日起取代） <class 'datetime.date'>
# 2024-05-01 劳动节 <class 'datetime.date'>
# 2024-05-02 休息日（2024-04-28日起取代） <class 'datetime.date'>
# 2024-05-03 休息日（2024-05-11日起取代） <class 'datetime.date'>
# 2024-06-10 端午节 <class 'datetime.date'>
# 2024-09-16 休息日（2024-09-14日起取代） <class 'datetime.date'>
# 2024-09-17 中秋节 <class 'datetime.date'>
# 2024-10-01 国庆节 <class 'datetime.date'>
# 2024-10-02 国庆节 <class 'datetime.date'>
# 2024-10-03 国庆节 <class 'datetime.date'>
# 2024-10-04 休息日（2024-09-29日起取代） <class 'datetime.date'>
# 2024-10-07 休息日（2024-10-12日起取代） <class 'datetime.date'>
# 2025-01-01 元旦 <class 'datetime.date'>
# 2025-01-29 春节 <class 'datetime.date'>
# 2025-01-30 春节 <class 'datetime.date'>
# 2025-01-31 春节 <class 'datetime.date'>
# 2025-04-04 清明节 <class 'datetime.date'>
# 2025-05-01 劳动节 <class 'datetime.date'>
# 2025-05-31 端午节 <class 'datetime.date'>
# 2025-06-02 端午节（观察日） <class 'datetime.date'>
# 2025-10-01 国庆节 <class 'datetime.date'>
# 2025-10-02 国庆节 <class 'datetime.date'>
# 2025-10-03 国庆节 <class 'datetime.date'>
# 2025-10-06 中秋节 <class 'datetime.date'>

# %%
# Specify the years you're interested in
years = range(2025, 2027)  # Replace with the years you need

# Create a China holidays object
cn_holidays = holidays.China(years=years)

# Iterate over the holidays and print them
for date, name in sorted(cn_holidays.items()):
    print(date, name)
# Out:
# 2025-01-01 元旦
# 2025-01-29 春节
# 2025-01-30 春节
# 2025-01-31 春节
# 2025-04-04 清明节
# 2025-05-01 劳动节
# 2025-05-31 端午节
# 2025-06-02 端午节（观察日）
# 2025-10-01 国庆节
# 2025-10-02 国庆节
# 2025-10-03 国庆节
# 2025-10-06 中秋节
# 2026-01-01 元旦
# 2026-02-17 春节
# 2026-02-18 春节
# 2026-02-19 春节
# 2026-04-05 清明节
# 2026-04-06 清明节（观察日）
# 2026-05-01 劳动节
# 2026-06-19 端午节
# 2026-09-25 中秋节
# 2026-10-01 国庆节
# 2026-10-02 国庆节
# 2026-10-03 国庆节
# 2026-10-05 国庆节（观察日）

# %%
datetime.date(2025, 2, 3).strftime("%Y-%m-%d")
# Out:
# '2025-02-03'

# %%
import chinese_calendar
import datetime
chinese_calendar.is_holiday(datetime.date(2025, 2, 3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import chinese_calendar
#       2 import datetime
#       3 chinese_calendar.is_holiday(datetime.date(2025, 2, 3))
#
# ModuleNotFoundError: No module named 'chinese_calendar'

# %%
# from neuralprophet.event_utils import get_all_holidays
import holidays
import pandas as pd
from collections import deque
import chinese_calendar


def check_holiday(date, country_holidays):
    return country_holidays[date] if date in country_holidays else None


def get_holidays(years, region):
    if region == "CN":
        return {pd.to_datetime(k): v for k, v in chinese_calendar.constants.holidays.items() if k.year in years}
    else:
        return {
            pd.to_datetime(k): v
            for k, v in holidays.country_holidays(years=years, country=region)
        }


def shift_series_with_holiday(df: pd.DataFrame, region) -> pd.DataFrame:
    df = df.copy()
    df.set_index("date", inplace=True)
    df.sort_index(inplace=True)

    # Initialize variables
    variable_queue = deque()
    shifted_data = []

    # Define all dates needed, extending beyond the original data if necessary
    start_date = df.index.min()
    # We add extra days to accommodate shifted values beyond the original date range
    end_date = df.index.max() + pd.Timedelta(days=len(df))
    all_dates = pd.DataFrame(
        {"date": pd.bdate_range(start=start_date, end=end_date), "holiday": None}
    )
    country_holidays = get_holidays(all_dates["date"].dt.year.unique(), region)
    # all_dates["date"] = all_dates["date"].dt.strftime("%Y-%m-%d")
    all_dates.loc[:, "holiday"] = all_dates["date"].apply(
        lambda x: check_holiday(x, country_holidays)
    )

    # Identify variable columns
    variable_columns = [col for col in df.columns if col not in ("date", "holiday")]

    for date_row in all_dates.itertuples():
        current_date = date_row.date
        holiday = date_row.holiday
        # Check if we have exhausted the original data
        if current_date in df.index:
            row = df.loc[current_date]
            if pd.notnull(holiday):
                # Holiday: set variable values to zero for this date
                shifted_row = {"date": current_date, "holiday": holiday}
                shifted_row.update(
                    {col: 0 if col == "yhat_n" else None for col in variable_columns}
                )
                shifted_data.append(shifted_row)
                # Add the variable values to the queue for shifting
                variable_queue.append({col: row[col] for col in variable_columns})
            else:
                if variable_queue:
                    # Assign the oldest variable values from the queue
                    shifted_values = variable_queue.popleft()
                    shifted_row = {"date": current_date, "holiday": None}
                    shifted_row.update(shifted_values)
                    shifted_data.append(shifted_row)
                    # Add the current variable values to the queue
                    variable_queue.append({col: row[col] for col in variable_columns})
                else:
                    # No shifts needed, assign the current variable values
                    shifted_row = {"date": current_date, "holiday": None}
                    shifted_row.update({col: row[col] for col in variable_columns})
                    shifted_data.append(shifted_row)
        elif variable_queue:
            # No more original data, but there may be queued values to assign
            if pd.notnull(holiday):
                # Holiday: set variable values to zero for this date
                shifted_row = {"date": current_date, "holiday": holiday}
                shifted_row.update(
                    {col: 0 if col == "yhat_n" else None for col in variable_columns}
                )
                shifted_data.append(shifted_row)
            else:
                # Assign the oldest variable from the queue
                shifted_values = variable_queue.popleft()
                shifted_row = {"date": current_date, "holiday": None}
                shifted_row.update(shifted_values)
                shifted_data.append(shifted_row)
        else:
            # No data left to process
            break

    # Create the shifted DataFrame
    shifted_df = pd.DataFrame(shifted_data)
    shifted_df.set_index("date", inplace=True)

    # Drop any dates beyond the last assigned variable
    last_assigned_date = shifted_df["yhat_n"].last_valid_index()
    shifted_df = shifted_df.loc[:last_assigned_date]

    # Sort the DataFrame by date
    shifted_df.sort_index(inplace=True)
    shifted_df.reset_index(inplace=True)
    shifted_df.replace({np.nan: None}, inplace=True)

    return shifted_df

# %%
get_holidays([2025, 2026], region="CN")
# Out:
# {Timestamp('2025-01-01 00:00:00'): "New Year's Day",
#  Timestamp('2025-01-28 00:00:00'): 'Spring Festival',
#  Timestamp('2025-01-29 00:00:00'): 'Spring Festival',
#  Timestamp('2025-01-30 00:00:00'): 'Spring Festival',
#  Timestamp('2025-01-31 00:00:00'): 'Spring Festival',
#  Timestamp('2025-02-01 00:00:00'): 'Spring Festival',
#  Timestamp('2025-02-02 00:00:00'): 'Spring Festival',
#  Timestamp('2025-02-03 00:00:00'): 'Spring Festival',
#  Timestamp('2025-02-04 00:00:00'): 'Spring Festival',
#  Timestamp('2025-04-04 00:00:00'): 'Tomb-sweeping Day',
#  Timestamp('2025-04-05 00:00:00'): 'Tomb-sweeping Day',
#  Timestamp('2025-04-06 00:00:00'): 'Tomb-sweeping Day',
#  Timestamp('2025-05-01 00:00:00'): 'Labour Day',
#  Timestamp('2025-05-02 00:00:00'): 'Labour Day',
#  Timestamp('2025-05-03 00:00:00'): 'Labour Day',
#  Timestamp('2025-05-04 00:00:00'): 'Labour Day',
#  Timestamp('2025-05-05 00:00:00'): 'Labour Day',
#  Timestamp('2025-05-31 00:00:00'): 'Dragon Boat Festival',
#  Timestamp('2025-06-01 00:00:00'): 'Dragon Boat Festival',
#  Timestamp('2025-06-02 00:00:00'): 'Dragon Boat Festival',
#  Timestamp('2025-10-01 00:00:00'): 'National Day',
#  Timestamp('2025-10-02 00:00:00'): 'National Day',
#  Timestamp('2025-10-03 00:00:00'): 'National Day',
#  Timestamp('2025-10-04 00:00:00'): 'National Day',
#  Timestamp('2025-10-05 00:00:00'): 'National Day',
#  Timestamp('2025-10-06 00:00:00'): 'Mid-autumn Festival',
#  Timestamp('2025-10-07 00:00:00'): 'National Day',
#  Timestamp('2025-10-08 00:00:00'): 'National Day'}

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
import numpy as np
# Define your start and end dates
start_date = "2025-01-01"  # Replace with your start date
end_date = "2025-09-30"  # Replace with your end date

# Generate a business day date range
business_days = pd.bdate_range(start=start_date, end=end_date)

# Create a DataFrame with the date range and a 'holiday' column initialized to None
df = pd.DataFrame({"date": business_days})
# df["date"] = df["date"].dt.strftime("%Y-%m-%d")
df["holiday"] = None
df["yhat_n"] = np.random.rand(len(df))
df["trend"] = np.random.rand(len(df))

# %%
df.dtypes
# Out:
# date       datetime64[ns]
# holiday            object
# yhat_n            float64
# trend             float64
# dtype: object

# %%
df
# Out:
#           date holiday    yhat_n     trend
# 0   2025-01-01    None  0.143940  0.811856
# 1   2025-01-02    None  0.869732  0.034603
# 2   2025-01-03    None  0.252077  0.501068
# 3   2025-01-06    None  0.991789  0.470418
# 4   2025-01-07    None  0.721227  0.938736
# 5   2025-01-08    None  0.769377  0.242920
# 6   2025-01-09    None  0.295124  0.415246
# 7   2025-01-10    None  0.263360  0.017935
# 8   2025-01-13    None  0.242435  0.864813
# 9   2025-01-14    None  0.987914  0.608997
# 10  2025-01-15    None  0.456845  0.892920
# 11  2025-01-16    None  0.267928  0.919768
# 12  2025-01-17    None  0.114473  0.201690
# 13  2025-01-20    None  0.259217  0.166919
# 14  2025-01-21    None  0.470414  0.912386
# 15  2025-01-22    None  0.612464  0.685406
# 16  2025-01-23    None  0.259086  0.636875
# 17  2025-01-24    None  0.709030  0.268698
# 18  2025-01-27    None  0.175542  0.817348
# 19  2025-01-28    None  0.023658  0.153757
# 20  2025-01-29    None  0.684389  0.512971
# 21  2025-01-30    None  0.081147  0.156181
# 22  2025-01-31    None  0.215842  0.011286
# 23  2025-02-03    None  0.258890  0.997795
# 24  2025-02-04    None  0.095804  0.052028
# 207 2025-10-17                  None  0.032865  0.433697
# 208 2025-10-20                  None  0.905522  0.837327
# 209 2025-10-21                  None  0.286334  0.828102
# 210 2025-10-22                  None  0.635705  0.456808
# 211 2025-10-23                  None   0.39901  0.071314
# 212 2025-10-24                  None  0.267269  0.449281

# %%
import pandas as pd
import numpy as np
from collections import deque

# Sample DataFrame
data = {
    "date": pd.to_datetime(
        [
            "2023-10-01",
            "2023-10-02",
            "2023-10-03",
            "2023-10-04",
            "2023-10-05",
            "2023-10-06",
            "2023-10-07",
        ]
    ),
    "yhat_n": [1, 2, 3, 4, 5, 6, 7],
    "holiday": [None, None, "Holiday", None, None, "Holiday", None],
}
df = pd.DataFrame(data)
df.set_index("date", inplace=True)

# Initialize variables
variable_queue = deque()
shifted_data = []

# Define all dates needed, extending beyond the original data if necessary
start_date = df.index.min()
# We add extra days to accommodate shifted values beyond the original date range
end_date = df.index.max() + pd.Timedelta(days=len(df))
all_dates = pd.DataFrame({
    'date': pd.bdate_range(start=start_date, end=end_date),
    'holiday': None
})
# all_dates.reset_index(inplace=True)

# Identify variable columns
variable_columns = [col for col in df.columns if col not in ("date", "holiday")]

for date_row in all_dates.itertuples():
    current_date = date_row.date
    # Check if we have exhausted the original data
    if current_date in df.index:
        row = df.loc[current_date]
        holiday = date_row.holiday
        # holiday = row["holiday"]
        if pd.notnull(holiday):
            # Holiday: set variable values to zero for this date
            shifted_row = {"date": current_date, "holiday": holiday}
            shifted_row.update({col: 0 if col == 'yhat_n' else None for col in variable_columns})
            shifted_data.append(shifted_row)
            # Add the variable values to the queue for shifting
            variable_queue.append({col: row[col] for col in variable_columns})
        else:
            if variable_queue:
                # Assign the oldest variable values from the queue
                shifted_values = variable_queue.popleft()
                shifted_row = {"date": current_date, "holiday": None}
                shifted_row.update(shifted_values)
                shifted_data.append(shifted_row)
                # Add the current variable values to the queue
                variable_queue.append({col: row[col] for col in variable_columns})
            else:
                # No shifts needed, assign the current variable values
                shifted_row = {"date": current_date, "holiday": None}
                shifted_row.update({col: row[col] for col in variable_columns})
                shifted_data.append(shifted_row)
    else:
        # No more original data, but there may be queued values to assign
        if variable_queue:
            # Assign the oldest variable from the queue
            shifted_values = variable_queue.popleft()
            shifted_row = {"date": current_date, "holiday": None}
            shifted_row.update(shifted_values)
            shifted_data.append(shifted_row)
        else:
            # No data left to process
            break

# Create the shifted DataFrame
shifted_df = pd.DataFrame(shifted_data)
shifted_df.set_index("date", inplace=True)

# Drop any dates beyond the last assigned variable
last_assigned_date = shifted_df["yhat_n"].last_valid_index()
shifted_df = shifted_df.loc[:last_assigned_date]

# Sort the DataFrame by date
shifted_df.sort_index(inplace=True)
shifted_df.reset_index(inplace=True)

# Display the final DataFrame
print(shifted_df)
# Out:
#         date holiday  yhat_n
# 0 2023-10-02    None       2
# 1 2023-10-03    None       3
# 2 2023-10-04    None       4
# 3 2023-10-05    None       5
# 4 2023-10-06    None       6
